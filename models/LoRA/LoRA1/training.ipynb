# %%
# !pip install transformers
# !pip install peft
# !pip install dataclasses
# !pip install --upgrade wandb

# %%
# pip uninstall -y wandb

# %%
# pip install wandb

# %%
# import wandb
# print(wandb.__version__)

# %%
import wandb
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: 19010247shim (19010247shim-sejong-university). Use `wandb login --relogin` to force relogin
# True

# %%
import transformers
from transformers import TrainingArguments, Trainer, AutoTokenizer, AutoModelForCausalLM
from transformers.trainer_callback import EarlyStoppingCallback
import torch
from torch.utils.data import Dataset
from peft import LoraConfig, get_peft_model
from dataclasses import dataclass
import json, os, random, logging, math, copy
import numpy as np

IGNORE_INDEX = -100 # 학습 loss 계산에 무시되는 index
os.environ['WANDB_PROJECT'] = 'TEST' # wandb project 이름 설정

# %%
# random seed 설정 함수
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

# %%
def load_dataset(directory_path):
    filenames = os.listdir(directory_path)
    datas = []
    for filename in filenames:
        with open(os.path.join(directory_path, filename), 'r', encoding='utf8') as f:
            file_data = json.load(f)
            if isinstance(file_data, list):
                datas.extend(file_data)
            else:
                datas.append(file_data)

    print(f"loading finished : {len(datas)} datas")
    return datas

def data_transform(datas):
    prompt_template = (
        "당신은 대한민국 경상북도 경산시 부동산 전문가입니다. "
        "다음 입력정보에 따라 적절한 공실 순위와, 분석을 생성하세요.\n"
        "### 입력 정보:\n{features}\n\n### 분석 결과:\n"
    )

    dataset = []
    for data in datas:
        try:
            reasoning_result = json.loads(data.get('reasoning_result', '{}'), strict=False)
        except json.JSONDecodeError as e:
            print(f"Warning: Skipping data point due to JSONDecodeError: {e}")
            print(f"Problematic data: {data.get('reasoning_result', '{}')}")
            continue

        # 'columns'만 가져오기
        columns = reasoning_result.get('features', {}).get('columns', {})
        if not columns:
            print("Warning: Skipping data point due to missing 'columns'")
            continue

        features = json.dumps(columns, ensure_ascii=False, indent=2)
        analysis = reasoning_result.get('analysis', '')

        source = prompt_template.format(features=features)
        target = analysis

        dataset.append(dict(
            source=source,
            target=target
        ))

    print(f"Total data samples: {len(dataset)}")

    return dataset

# %%
def preprocess(sources, targets, tokenizer):
    examples = [s + t for s, t in zip(sources, targets)]

    input_ids = tokenizer(text=examples, padding=False, return_attention_mask=False, return_length=False,
                          max_length=tokenizer.model_max_length, truncation=True, verbose=False)["input_ids"]
    labels = copy.deepcopy(input_ids)

    for pieces in input_ids:
        assert not any([math.isnan(piece) or math.isinf(piece) for piece in pieces])

    source_lens = tokenizer(text=sources, padding=False, return_attention_mask=False, return_length=True,
                            max_length=tokenizer.model_max_length, truncation=True, verbose=False)["length"]

    for example_index in range(len(examples)):
        for index in range(source_lens[example_index]):
            labels[example_index][index] = IGNORE_INDEX

    return dict(input_ids=input_ids, labels=labels)


class CustomDataset(Dataset):
    def __init__(self, examples, tokenizer):
        self.tokenizer = tokenizer

        sources = [example['source'] for example in examples]
        targets = [f"{example['target']}{tokenizer.eos_token}" for example in examples]

        logging.warning(msg="tokenizing...")
        data_dict = preprocess(sources=sources, targets=targets, tokenizer=tokenizer)
        logging.warning(msg="tokenizing finished")

        self.input_ids = data_dict["input_ids"]
        self.labels = data_dict["labels"]

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return dict(input_ids=self.input_ids[idx], labels=self.labels[idx])

@dataclass
class CustomCollator(object):
    tokenizer: transformers.PreTrainedTokenizer

    def __call__(self, instances):
        input_ids, labels = tuple([instance[key] for instance in instances] for key in ("input_ids", "labels"))
        input_ids = [torch.tensor(piece) for piece in input_ids]
        labels = [torch.tensor(piece) for piece in labels]

        input_ids = torch.nn.utils.rnn.pad_sequence([i.flip(dims=[-1]) for i in input_ids], batch_first=True, padding_value=self.tokenizer.pad_token_id).flip(dims=[1])
        labels = torch.nn.utils.rnn.pad_sequence([i.flip(dims=[-1]) for i in labels], batch_first=True, padding_value=IGNORE_INDEX).flip(dims=[1])

        return dict(input_ids=input_ids, labels=labels, attention_mask=input_ids.ne(self.tokenizer.pad_token_id))

# %%
def get_training_args(args):
    training_args = TrainingArguments(
        output_dir=args['output_dir'],
        evaluation_strategy="steps",
        load_best_model_at_end=False,
        metric_for_best_model="eval_loss",
        greater_is_better=False,
        learning_rate=args["learning_rate"],
        weight_decay=args["weight_decay"],
        push_to_hub=False,
        do_train=True,
        num_train_epochs=args['num_epochs'],
        per_device_train_batch_size=args["batch_size"],
        logging_steps=args["logging_steps"],
        gradient_accumulation_steps=args["accumulation_steps"],
        save_strategy="steps",
        save_steps=args["save_steps"],
        warmup_ratio=0.03,
        lr_scheduler_type='constant', #learning rate 고정.
        max_grad_norm=1.0,
        fp16=True,  #이전에는 false 였음. a100 쓸꺼니깐 문제없을듯.
        report_to=args["report_to"],
        run_name=args["run_name"],
    )

    return training_args

def get_lora_args(args):
    peft_config = LoraConfig(
        lora_alpha=128,  # 설정 명시적으로 분리
        lora_dropout=args['lora_dropout'],
        r=args['lora_r'],
        bias=args['bias'],
        task_type="CAUSAL_LM"
    )

    return peft_config

# %%
def training(config):
    # model and tokenizer load
    model = AutoModelForCausalLM.from_pretrained(pretrained_model_name_or_path=config['pretrained_model_name_or_path'],
                                                 trust_remote_code=config['trust_remote_code'],
                                                 cache_dir=config['cache_dir'],
                                                 local_files_only=config['local_files_only'])

    tokenizer = AutoTokenizer.from_pretrained(pretrained_model_name_or_path=config['pretrained_model_name_or_path'],
                                              trust_remote_code=config['trust_remote_code'],
                                              cache_dir=config['cache_dir'],
                                              local_files_only=config['local_files_only'],
                                              padding_side=config['padding_side'])

    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id
    tokenizer.model_max_length = config['max_token_length']

    # LoRA 적용
    lora_config = get_lora_args(config['lora_args'])
    model = get_peft_model(model, lora_config)

    # org dataset load
    train_dataset = load_dataset(config['train_data_path'])
    train_dataset = data_transform(train_dataset)

    # Ensure the directory exists
    os.makedirs(config['train_data_path'], exist_ok=True)
    train_dataset = load_dataset(config['train_data_path'])
    train_dataset = data_transform(train_dataset)


    # prepare train dataset
    train_dataset = CustomDataset(examples=train_dataset, tokenizer=tokenizer)
    data_collator = CustomCollator(tokenizer=tokenizer)

    # prepare training model
    training_args = get_training_args(config['training_args'])

    train_size = int(0.8 * len(train_dataset))
    eval_size = len(train_dataset) - train_size
    train_dataset, eval_dataset = torch.utils.data.random_split(train_dataset, [train_size, eval_size])

    trainer = Trainer(model=model,
                      tokenizer=tokenizer,
                      args=training_args,
                      train_dataset=train_dataset,
                      eval_dataset=eval_dataset,
                      data_collator=data_collator,
                      #callbacks=[EarlyStoppingCallback(early_stopping_patience=3, early_stopping_threshold=0.1)])
                      )

    # 학습 수행
    trainer.train()

    # 맨 마지막 - 학습 종료 이후 저장하는 부분
    trainer.save_state()
    trainer.save_model(output_dir=os.path.join(config['output_dir'],"final"))

# %%
# workspace/LoRA1/inputs1

#root_dir = os.path.abspath("LoRA1")
root_dir = "/workspace/LoRA1"
input_dir = os.path.join(root_dir, "inputs1")

# 반드시 경로 알잘딱 바꿔주기
model_name = "EleutherAI/polyglot-ko-1.3b" # beomi/llama-2-ko-7b , EleutherAI/polyglot-ko-1.3b
output_dir = os.path.join(root_dir, "outputs", model_name.split("/")[1], "test")
os.makedirs(output_dir, exist_ok=True)

cache_dir = os.path.join(root_dir, 'cache')

set_seed(seed=42)

config = {
    "training_args":{
        "output_dir": output_dir,
        "learning_rate": 2e-5,
        "weight_decay": 0.001,
        "batch_size": 6,
        "accumulation_steps": 32,
        "logging_steps": 1,
        "save_steps": 50,
        "num_epochs": 25,
        "report_to": "wandb",
        "run_name": "session_1227"
    },
    "lora_args": {
        "lora_r": 128,
        "lora_dropout": 0.05,
        "bias": "none"
    },


    "pretrained_model_name_or_path": model_name,
    "trust_remote_code": True,
    "cache_dir": cache_dir,
    "local_files_only": False,
    "padding_side": "left",
    "max_token_length": 4096,

    "train_data_path": input_dir,
    "output_dir": output_dir

}

training(config)
# Out:
# config.json:   0%|          | 0.00/640 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/31.6k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/1.00G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/1.02G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/748M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/164 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# loading finished : 4600 datas
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 395)
# Problematic data: {
#     "features": {
#         "group_id": 124,
#         "columns": {
#             "num_of_company": [139, 142, 149],
#             "num_of_large": [2, 2, 2],
#             "num_of_bus_stop": [11, 12, 13],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [3, 3, 3],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10467.092625317817, 10481.343809099148, 10452.50914080669],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['소매업', '소매업', '소매업'],
#             "avg_sales_level": [6.0, 5.0, 3.5]
#         }
#     },
#     "analysis": "경산시의 3개의 공실 중에서 경쟁 업체 수와 인프라, 교통 접근성, 대학교 접근성, 매출 등급 등을 종합적으로 고려해야 합니다. 첫 번째 공실은 경쟁 업체 수가 많고 매출 등급이 높은 편이지만, 대학교와 지하철 접근성이 부족합니다. 두 번째 공실은 경쟁 업체 수와 인프라, 교통 접근성이 보통 수준이며 매출 등급도 중간 정도입니다. 세 번째 공실은 경쟁 업체 수는 적지만 매출 등급이 낮고 대학교와 지하철 접근성이 좋습니다.",
#     "summary": "1위: 공실 2, 2위: 공실 1, 3위: 공실 3",
#     "rule_based_intent": "경쟁 업체 수가 적고 대학교 및 지하철 접근성이 우수한 공실 3이 가장 창업하기에 알맞습니다. 또한 인프라와 교통 접근성이 균형잡힌 공실 2가 두 번째로 선호되며, 경쟁 업체 수와 매출 등급이 높지만 대학교 및 지하철 접근성이 떨어지는 공실 1은 세 번째로 추천됩니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 392)
# Problematic data: {
#     "features": {
#         "group_id": 192,
#         "columns": {
#             "num_of_company": [213, 235, 235],
#             "num_of_large": [0, 1, 1],
#             "num_of_bus_stop": [4, 6, 7],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [11636.458741876531, 11472.60454661412, 11402.545758615828],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['도매업', '도매업', '도매업'],
#             "avg_sales_level": [4.0, 1.5, 3.25]
#         }
#     },
#     "analysis": "분석을 통해, 공실 1은 대기업이 없으며 주변 버스 정류장 수가 적은 편이고 주변 인프라 시설도 부족하여 잠재적인 고객 유입이 어려울 것으로 판단됩니다. 공실 2는 대기업이 1개 존재하며 버스 정류장 수가 증가하고 있으며, 평균 매출 등급이 낮은 편이므로 경쟁 강도가 높을 수 있습니다. 공실 3은 대기업이 1개 존재하고 근처에 지자체 사무실이 2개 있어 인프라가 상대적으로 우수하며, 평균 매출 등급도 중간 수준이기 때문에 성공 가능성이 높을 것으로 판단됩니다.",
#     "summary": "1. 공실 3 > 2. 공실 1 > 3. 공실 2",
#     "rule_based_intent": "경쟁 강도가 낮고 인프라가 우수하며 평균 매출 등급이 중간 수준인 공실 3이 창업하기에 가장 적합해 보입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 392)
# Problematic data: {
#     "features": {
#         "group_id": 219,
#         "columns": {
#             "num_of_company": [221, 220, 217],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [3, 6, 5],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10693.98845059832, 10684.94092642059, 10633.144466650036],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['서비스', '서비스', '서비스'],
#             "avg_sales_level": [2.0, 3.67, 5.0]
#         }
#     },
#     "analysis": "분석 결과, 3개의 공실 중 첫 번째 공실(번호 221)이 창업하기에 가장 적합합니다. 이는 해당 공실의 평균 매출 등급이 높아서 수익이 기대되며, 근처에 대로변이 있어 기업체 밀집도가 높고 교통편도 상대적으로 좋은 편이기 때문입니다. 또한 가까운 지하철 역이 없지만 버스 정류장이 있어 접근성이 보장되며, 대학과 가까워 잠재 고객 유입이 기대됩니다. 더불어 경쟁 강도도 적은 편입니다.",
#     "summary": "1. 공실 221\n2. 공실 220\n3. 공실 217",
#     "rule_based_intent": "가장 적합한 공실을 선택하는 기준은 평균 매출 등급, 근처 기업체 수, 교통 접근성, 대학교 접근성, 경쟁 강도 등을 종합적으로 고려하였습니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 23 column 181 (char 1340)
# Problematic data: {
#     "features": {
#         "group_id": 231,
#         "columns": {
#             "num_of_company": [228, 223, 228],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [12, 13, 12],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10996.198596941873, 11028.626092959594, 11068.01506071604],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["의료", "의료", "의료"],
#             "avg_sales_level": [5.9, 5.29, 5.33]
#         }
#     },
#     "analysis": "주어진 공실 정보를 종합적으로 분석해보면, 각 공실의 특징과 잠재적인 가치를 고려해야 합니다. 먼저, 인근 인프라 측면에서는 회사 수가 안정적이며 대규모 기업이 한 곳에 집중되어 있습니다. 버스 정류장 수도 적정 수준이며 병원, 캠프장, 학교 등의 시설은 부족한 편입니다. 또한, 지하철까지의 거리가 비교적 가까우면서 지방자치단체 사무실의 수도 2곳으로 충분합니다. 이 외에도 주변에 공원과 주차장이 부족한 상황입니다. 평균 매출 등급은 5.29에서 5.9로 변동폭이 있습니다. 이러한 요소들을 종합적으로 고려할 때, 고객 유입이 보다 활발하고 경쟁이 적은 공실을 선택해야 합니다.",
#     "summary": "1. 첫 번째 공실(인덱스 0) : 평균 매출 등급이 가장 높은 5.9로, 고객 유입이 활발할 것으로 기대됩니다. 대규모 기업이 몰려있고 버스 정류장 수가 적정합니다. 또한, 인근에 지하철 역이 가깝고 지방자치단체 사무실도 2곳으로 안정적입니다. 부족한 공원과 주차장을 보완할 필요가 있습니다.\
# 2. 두 번째 공실(인덱스 1) : 평균 매출 등급이 5.29로 낮긴 하지만, 대부분의 요소들이 첫 번째 공실과 유사합니다. 고객 유입이 가능하며, 인프라도 안정적입니다. 보완할 부분은 있다 하더라도 경쟁이 적을 것으로 판단됩니다.\
# 3. 세 번째 공실(인덱스 2) : 평균 매출 등급이 5.33으로 두 번째 공실과 비슷하나, 첫 번째 공실에 비해 약간 부족한 면이 있습니다. 고객 유입이 가능하나, 미흡한 부분을 보완해야 합니다.",
#     "rule_based_intent": "가장 알맞은 공실은 첫 번째 공실(인덱스 0)입니다. 이유로는 평균 매출 등급이 가장 높고, 인근 인프라 및 경쟁도 적합한 수준이며 고객 유입이 활발할 것으로 판단되기 때문입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Problematic data: ```json
# {
#     "features": {
#         "group_id": 321,
#         "columns": {
#             "num_of_company": [223, 225, 227],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [13, 10, 11],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11028.626092959594, 11152.496743132018, 11092.710477666937],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["도매업", "도매업", "도매업"],
#             "avg_sales_level": [3.71, 4.0, 3.69]
#         }
#     },
#     "analysis": "평균 매출 등급을 고려할 때, 공실 2가 4.0으로 가장 높고, 그 다음이 공실 1(3.71), 마지막이 공실 3(3.69)이다. 인근 인프라 측면에서 공실 1과 공실 2는 기업체 수와 국공립 대학교가 인근에 있지만 버스 정류장 수가 적고 병원, 주차장, 공원이 없다. 공실 3은 인근 인프라에서는 기업체 수는 높지만 국공립 대학교가 없고, 버스 정류장 수는 높지 않지만 주변에 병원과 공원이 있어서 유리하다. 교통 접근성 측면에서도 공실 1과 공실 2는 지하철이 없고, 버스 정류장은 적으나 거리는 비슷하다. 공실 3은 지하철까지의 거리가 가장 가깝고 버스 정류장 수도 적당하다. 종합적으로 볼 때, 대학생을 중심으로 매출을 기대하는 경우에는 공실 2가 유리하고, 일반 가정을 대상으로 한다면 공실 3이 유리할 것으로 판단된다.",
#     "summary": "1. 공실 2 (평균 매출 등급: 4.0)
#     2. 공실 1 (평균 매출 등급: 3.71)
#     3. 공실 3 (평균 매출 등급: 3.69)",
#     "rule_based_intent": "경산시 15년 이상 경력 보유 창업 전문 컨설턴트의 의견에 의하면, 공실 2가 가장 알맞을 수 있으며, 다음으로 공실 1을 선택하는 것이 좋을 것으로 판단된다."
# }
# ```
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 69 (char 880)
# Problematic data: {
#     "features": {
#         "group_id": 344,
#         "columns": {
#             "num_of_company": [228, 228, 227],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [12, 12, 11],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11086.30601542057, 11068.01506071604, 11092.710477666937],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["교육", "교육", "교육"],
#             "avg_sales_level": [3.0, 3.0, 3.0]
#         }
#     },
#     "analysis": "주어진 정보를 종합적으로 고려해본 결과, 경쟁 강도가 낮고 교통 접근성 및 인프라가 양호한 \'교육\' 업종의 공실이 창업하기에 가장 알맞을 것으로 판단됩니다. 해당 업종의 평균 매출 등급은 3.0으로 안정적이며, 주변에 대규모 기업체도 적고 경쟁사가 별로 없어 경쟁 강도가 낮습니다. 또한, 버스 정류장이 많고 근처에 지하철이 있으며, 공원과 주차장 등 인프라도 잘 갖추어져 있습니다. 이에 공실 개발을 통해 학원이나 교육 관련 업체를 창업하는 것이 유망할 것으로 판단됩니다.",
#     "summary": "1. 교육 업종의 공실\n2. 간이식품 업종의 공실\n3. 헬스케어 업종의 공실",
#     "rule_based_intent": "교육 업종의 공실을 우선 선택하여 창업을 진행하고자 함"
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 75 (char 889)
# Problematic data: {
#     "features": {
#         "group_id": 2385,
#         "columns": {
#             "num_of_company": [661, 673, 623],
#             "num_of_large": [0, 0, 0],
#             "num_of_bus_stop": [6, 6, 5],
#             "num_of_hospital": [1, 1, 1],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [7463.615542476264, 7369.390869412375, 7676.346211548558],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [1, 1, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["유흥주점", "유흥주점", "유흥주점"],
#             "avg_sales_level": [3.0, 3.0, 3.0]
#         }
#     },
#     "analysis": "3개의 공실 중에서 성공을 이루기 위한 우선순위를 정하기 위해 다음의 요소를 종합적으로 고려하였습니다.\
#     첫째, 평균 매출 등급인 평균 3.0은 모든 공실이 비슷한 수준으로 경쟁력을 나타내고 있습니다.\
#     둘째, 인근 인프라 측면에서는 버스 정류장과 학교가 유력한 잠재 고객 유입 요인으로 작용하며, 공원이 있는 지역이 다소 우세합니다.\
#     셋째, 교통 접근성은 지하철이 없으며 버스 정류장이 상대적으로 많은 지역이어서 대중교통 이용이 편리할 것으로 예상됩니다.\
#     이러한 요소들을 종합적으로 고려하여 창업 성공 가능성을 판단하였습니다.",
#     "summary": "1. 공실 2\n2. 공실 1\n3. 공실 3",
#     "rule_based_intent": "공실 2이 성공을 이루기에 더 알맞은 지역으로 판단됩니다. 이유는 버스 정류장과 학교가 유리한 위치적 장점이 있고, 공원도 주변에 있어 생활 환경이 좋을 것으로 예상됩니다. 또한, 지하철과 버스 정류장이 근접해 대중교통 이용이 용이할 것으로 예상됩니다. 이에 따라 공실 2를 우선적인 창업 위치로 고려할 것을 권장합니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 395)
# Problematic data: {
#     "features": {
#         "group_id": 409,
#         "columns": {
#             "num_of_company": [121, 120, 116],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [12, 10, 11],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 0],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10443.658239411248, 10484.005066029456, 10286.074307823174],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 0],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['음식점', '음식점', '음식점'],
#             "avg_sales_level": [2.0, 2.0, 2.0]
#         }
#     },
#     "analysis": "주어진 3개의 공실은 모두 음식점 업종에 속하며, 평균 매출 등급은 모두 2.0으로 동일합니다. 인근 인프라 측면에서는 기업체 수와 버스 정류장 수가 유사하나 병원, 공원, 주차장 등의 시설은 전부 0입니다. 대학교 접근성은 경산시에서 중요한 요소이며, 모든 공실이 영남대와 가까운 거리에 위치하고 있습니다. 따라서, 이들은 잠재 고객 유입 면에서 살펴봤을 때 경쟁 요인이 유사합니다. 그러나 지하철 거리는 3번 공실이 다소 더 가까운 것으로 나타나며, 이는 교통 접근성을 고려할 때 차별적인 요소로 작용할 수 있습니다. 종합적으로 보았을 때, 3번 공실이 경쟁 강도 측면에서 약간 유리하며 실제로 창업이 성공할 가능성을 조금 더 높일 수 있을 것으로 판단됩니다.",
#     "summary": "3번 > 1번 = 2번",
#     "rule_based_intent": "3번 공실이 가장 알맞은 공실이며, 우선순위는 3번 > 1번 = 2번 입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting property name enclosed in double quotes: line 25 column 1 (char 1123)
# Problematic data: {
#     "features": {
#         "group_id": 458,
#         "columns": {
#             "num_of_company": [238, 233, 235],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [5, 6, 7],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11467.874093239005, 11476.258816602636, 11402.545758615828],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["음식점", "음식점", "음식점"],
#             "avg_sales_level": [2.73, 2.73, 2.8]
#         }
#     },
#     "analysis": "이 분석에서는 세 공실 중 경쟁 강도, 인근 인프라, 교통 접근성, 대학교 접근성, 평균 매출 등급 등 다양한 요인을 종합적으로 고려하여 최적의 창업 장소를 선정할 것입니다.",
#     "summary": "1. 공실 3\n2. 공실 1\n3. 공실 2",
#     "rule_based_intent": "경쟁 강도가 낮고, 대학교 근접성이 높으며, 인근 인프라 및 교통 접근성이 적절한 '공실 3'이 가장 적합하다. '공실 1'은 경쟁 강도가 다소 높고 '공실 2'는 대학교 근접성이 낮기 때문에 보다 뒷 순위다.",
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 88 (char 900)
# Problematic data: {
#     "features": {
#         "group_id": 486,
#         "columns": {
#             "num_of_company": [217, 216, 217],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [5, 5, 6],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 2, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10633.144466650036, 10595.838119470383, 10646.38517617251],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["교육", "교육", "교육"],
#             "avg_sales_level": [1.25, 1.25, 1.25]
#         }
#     },
#     "analysis": "주어진 데이터를 종합적으로 분석한 결과, 성공적인 창업을 위해 가장 적합한 공실은 '공실 2'입니다. 이유는 다음과 같습니다.\
#     먼저, '공실 2'는 인근에 대형 기업체가 존재하며, 버스 정류장 수가 다른 공실에 비해 더 많습니다. 또한, 학교가 2개로 다른 공실에 비해 더 많은 교육 시설이 위치해 있습니다. 이는 잠재 고객 유입을 촉진할 수 있습니다.\
#     또한, 주변 경쟁업체인 기타관련 시설의 수가 다른 공실과 비슷하며, 교통 접근성 측면에서도 차별화가 크지 않습니다. 그러나 대학교와 가장 가까운 지하철 역까지의 거리도 다른 공실과 크게 차이나지 않습니다.\
#     따라서, '공실 2'는 다른 공실에 비해 더 많은 기업체와 교육 시설이 위치해 있으며, 이는 창업 성공에 긍정적인 영향을 줄 수 있습니다.",
#     "summary": "1. 공실 2\n2. 공실 1\n3. 공실 3",
#     "rule_based_intent": "가장 알맞은 공실 선택"
# }
# Warning: Skipping data point due to JSONDecodeError: Extra data: line 26 column 1 (char 1210)
# Problematic data: {
#     "features": {
#         "group_id": 1411,
#         "columns": {
#             "num_of_company": [221, 220, 217],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [3, 6, 5],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10693.98845059832, 10684.94092642059, 10633.144466650036],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["도매업", "도매업", "도매업"],
#             "avg_sales_level": [3.33, 3.33, 3.33]
#         }
#     },
#     "analysis": "주어진 정보를 종합적으로 고려할 때, 창업하기 가장 적합한 공실을 평가하기 위해 다음 요소들을 고려할 것입니다. 먼저, 평균 매출 등급은 모두 3.33으로 동일하나, 인근 인프라 측면에서는 기업체 수, 버스 정류장 수, 병원 수 등이 중요합니다. 교통 접근성 측면에서는 지하철 거리 및 대중교통 시설도 고려해야 합니다. 또한, 경쟁 강도와 대학 접근성 또한 중요한 평가 요소입니다.",
#     "summary": "1. 첫 번째 공실(인덱스 0)\n2. 두 번째 공실(인덱스 1)\n3. 세 번째 공실(인덱스 2)",
#     "rule_based_intent": "가장 적합한 공실을 선정하기 위해 주변 인프라 및 교통 접근성 등을 고려하여 종합적으로 판단하였습니다."
# }
# 위의 분석과정을 토대로, 가장 적합한 공실은 인덱스 0에 해당하는 공실이라고 판단했습니다. 인근 인프라 및 교통 접근성 측면에서 두 번째 공실이 더욱 유리하며, 평균 매출 등급 또한 동일한 수준이므로 종합적으로 선정하였습니다.
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 396)
# Problematic data: {
#     "features": {
#         "group_id": 1467,
#         "columns": {
#             "num_of_company": [228, 228, 228],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [12, 12, 12],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10996.198596941873, 11068.01506071604, 11086.30601542057],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['교육', '교육', '교육'],
#             "avg_sales_level": [3.0, 3.0, 3.0]
#         }
#     },
#     "analysis": "주어진 세 공실은 모두 교육 업종이며, 평균 매출 등급은 모두 3.0으로 동일합니다. 인근 인프라 측면에서는 기업체 수, 버스 정류장 수, 병원 수, 주차장, 공원 등의 요소가 0에 가깝고, 대학교인 '영남대'와 가장 인접한 지하철 역까지의 거리는 10km 내외로 유사합니다.",
#     "summary": "1. 첫 번째 공실\n2. 두 번째 공실\n3. 세 번째 공실",
#     "rule_based_intent": ""
# }
# Warning: Skipping data point due to JSONDecodeError: Extra data: line 26 column 5 (char 891)
# Problematic data: {
#     "features": {
#         "group_id": 1909,
#         "columns": {
#             "num_of_company": [215, 213, 216],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [14, 13, 14],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [2, 2, 2],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10615.066432083388, 10633.097783120093, 10635.539377606498],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [3, 3, 3],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["도매업", "도매업", "도매업"],
#             "avg_sales_level": [4.1, 4.1, 4.1]
#         }
#     },
#     "analysis": "",
#     "summary": "",
#     "rule_based_intent": ""
# }
#     현재 공실 데이터에 대한 분석을 통해 어떤 공실이 창업하기에 가장 알맞은지와 그 이유에 대해 알려드릴 것입니다. 잠시만 기다려주세요.
# Warning: Skipping data point due to JSONDecodeError: Expecting ',' delimiter: line 22 column 117 (char 933)
# Problematic data: {
#     "features": {
#         "group_id": 1015,
#         "columns": {
#             "num_of_company": [238, 233, 235],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [5, 6, 6],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11467.874093239005, 11476.258816602636, 11472.60454661412],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 0],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["음식점", "음식점", "음식점"],
#             "avg_sales_level": [2.73, 2.73, 2.82]
#         }
#     },
#     "analysis": "공실들을 ganzify ㄴ부문에ㄴㅅㄱ 총합 정해요 장세래 뜨 하습니다 뭐 창업 디아날시스와 players 룰셋 악세서리 총합 합니다. Ju gyofire'호보 하시뜨 발음 시가"ㅅ행 줄나경 녹시정시 경훈이 있어도 훨 iris ㅇ러 힙습니다 상 동 경문 구성 월이의 특매경놋요에 대란'해요 월화입니다 l함윤 문네느 발집시켰요 네까 일 경련이 사용 방아요 다히의 모력을확으a 하시의 확마기입니다. Cat의 경련들이며 화 사용 발명제호외 부시열의 저장마경초 담시여킨 담모력부실크미 맛샤리기 굳었확마기 개마세글앞 렬화을 팔해인믜 mitionsㄴㅅㅠ총합매의오 화치오히왓함요 잘생입들의 s야용 바어확인하용 바럼입니다 모시림의 방정비 담변겠이 온정변에 관한 정보인 완문해임 그신 경림은 포줘비성입 대래 똥입 에대 길곡결입 성공했경에 관하 감랑누 t하기 위한 정보인 ㅊ기라인"ㅅ등진뎅르오화영치마지기 이혼 진화 have 정 미호럽방뱁 지정기잇 a 양 불충정양 eiㄴ경은경별복요이다네확마진온환ㄴ이 방카미복려신 "이 di끼정하일희된경방 끠정의호히로가오희인한정양에세 힙환시간핼경에를경입림해정용할 요"
#
#     "summary": "1위: 공실 3 (평균 매출 등급 2.82, 인근 인프라 수치 고려 시 우수)\n2위: 공실 1 (평균 매출 등급 2.73, 인근 인프라 수치 중간)\n3위: 공실 2 (평균 매출 등급 2.73, 인근 인프라 수치 중간)"
#
#     "rule_based_intent": "공실 3을 우선 선택하는 것이 적합합니다. 이유는 발명하는 기법을 바탕으로 매출 등급이 가장 높고 인근 인프라 수치가 우수하기 때문입니다. 다음으로는 공실 1을 고려할 수 있으며, 공실 2는 가장 마지막으로 고려하는 것이 좋습니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 23 column 66 (char 1182)
# Problematic data: {
#     "features": {
#         "group_id": 1026,
#         "columns": {
#             "num_of_company": [199, 202, 182],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [15, 17, 16],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 2, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10382.046980649531, 10459.980463169948, 10358.80742765456],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["소매업", "소매업", "소매업"],
#             "avg_sales_level": [3.97, 3.91, 4.03]
#         }
#     },
#     "analysis": "평균 매출 등급을 비교해 본 결과, 3번 공실이 4.03으로 가장 높은 평균 매출 등급을 보유하고 있습니다. 인근 인프라 측면에서는 1번, 2번, 3번 공실 모두 주요 인프라 요소들의 수치가 유사하며 별다른 차이가 나타나지 않습니다. 교통 접근성 측면에서는 가장 가까운 지하철 역까지의 거리가 1번 공실이 평균적으로 가장 짧은 것을 고려하였을 때 우수한 접근성을 제공합니다. 또한, 경쟁 강도를 고려할 때 2번 공실이 지방청사 수가 1개로 가장 적기 때문에 경쟁이 비교적 적을 것으로 예상됩니다.",
#     "summary": "1. 3번 공실 (평균 매출 등급: 4.03, 가장 가까운 지하철 역까지의 거리가 짧음)\
#                 2. 1번 공실 (평균 매출 등급: 3.97)\
#                 3. 2번 공실 (평균 매출 등급: 3.91, 지방청사 수가 증가함)",
#     "rule_based_intent": "3번 공실이 가장 알맞는 공실으로 평가됩니다. 3번 공실은 더 높은 평균 매출 등급과 교통 접근성을 제공하며, 경쟁이 비교적 적을 것으로 예상됩니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 23 column 104 (char 1124)
# Problematic data: {
#     "features": {
#         "group_id": 1038,
#         "columns": {
#             "num_of_company": [194, 193, 186],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [11, 8, 11],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [2, 2, 2],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10255.951585150711, 10288.199427521618, 10116.476375455955],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["유흥주점", "유흥주점", "유흥주점"],
#             "avg_sales_level": [2.83, 2.8, 2.62]
#         }
#     },
#     "analysis": "주어진 공실 정보를 종합적으로 분석한 결과, 경산시 내에서 유흥주점을 창업하고자 한다면 평균 매출 등급은 2.83인 공실을 선택하는 것이 가장 적합합니다. 이유는 해당 공실이 기업체 수와 교통편 등 여러 측면에서 유리하며, 경쟁 강도와 대학교 접근성도 고려할 때 가장 유망한 잠재 고객 유입 요인을 갖고 있기 때문입니다.",
#     "summary" : "1. 공실 1 (평균 매출 등급 2.83, 기업체 수 194, 버스 정류장 수 11, 주차장/공원 X, 지하철 거리 10255.95m, 경쟁 강도 높음) \
#                 \n2. 공실 2 (평균 매출 등급 2.8, 기업체 수 193, 버스 정류장 수 8, 주차장/공원 X, 지하철 거리 10288.20m, 경쟁 강도 높음) \
#                 \n3. 공실 3 (평균 매출 등급 2.62, 기업체 수 186, 버스 정류장 수 11, 주차장/공원 X, 지하철 거리 10116.48m, 경쟁 강도 높음)",
#     "rule_based_intent": "유흥주점 창업 시, 공실 1이 가장 적합하며, 순위는 공실 1 > 공실 2 > 공실 3 순서입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 396)
# Problematic data: {
#     "features": {
#         "group_id": 1716,
#         "columns": {
#             "num_of_company": [127, 132, 134],
#             "num_of_large": [2, 1, 0],
#             "num_of_bus_stop": [10, 10, 10],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [9911.71869550182, 9808.22819178371, 9656.129440660996],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['유흥주점', '유흥주점', '유흥주점'],
#             "avg_sales_level": [2.5, 2.57, 2.5]
#         }
#     },
#     "analysis": "분석 결과, 공실 3의 경우 대부분 요소들이 유사하나, 평균 매출 등급과 주변 인프라, 교통 접근성을 종합해 보았을 때, 공실 3이 가장 적합한 것으로 판단됩니다. 이유는 평균 매출 등급이 상대적으로 높고, 인근 인프라, 교통 접근성 요소들이 안정적이며 경쟁 강도가 낮은 것으로 나타났기 때문입니다.",
#     "summary": "1. 공실 3\n2. 공실 1\n3. 공실 2",
#     "rule_based_intent": "공실 3이 창업하기 가장 알맞은 공실로 판단되며, 공실 1이 그 다음으로, 공실 2가 순위에서 마지막에 위치합니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 395)
# Problematic data: {
#     "features": {
#         "group_id": 2144,
#         "columns": {
#             "num_of_company": [470, 477, 469],
#             "num_of_large": [0, 0, 0],
#             "num_of_bus_stop": [10, 10, 9],
#             "num_of_hospital": [0, 1, 1],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 0],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [8190.68, 8029.53, 7863.60],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['의료', '의료', '의료'],
#             "avg_sales_level": [4.43, 4.43, 4.67]
#         }
#     },
#     "analysis": "분석 결과를 통해 세 공실 모두 의료 산업에 속하며, 평균 매출등급은 공실1(4.43), 공실2(4.43), 공실3(4.67) 순서로 나타났습니다. 대규모 기업이 없으며 주변 환경에서는 주요 인프라 요소들의 수가 크게 차이나지 않았습니다. 교통 접근성 측면에서는 세 공실 모두 지하철 근접 거리 및 정류장 수가 유의미한 차이를 보이진 않았습니다. 그러나 대학교 접근성 면에서는 공실1과 공실2가 대학과 가장 가까운데 반해, 공실3은 대학과 거리가 약간 떨어져 있습니다.",
#     "summary": "1. 공실1, 2. 공실2, 3. 공실3",
#     "rule_based_intent": "공실1과 공실2는 매출 등급과 인근 대학교 접근성 면에서 우세하며, 공실1이 경쟁 강도 면에서 더 유리할 수 있습니다. 따라서, 세 공실 중에는 공실1이 가장 적합해 보이며, 그 다음으로 공실2가 그 뒤를 잇습니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 393)
# Problematic data: {
#     "features": {
#         "group_id": 2196,
#         "columns": {
#             "num_of_company": [592, 596, 596],
#             "num_of_large": [0, 0, 0],
#             "num_of_bus_stop": [8, 9, 4],
#             "num_of_hospital": [1, 1, 1],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [3, 2, 3],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [6936.881928916749, 6690.544752185848, 6860.749165900308],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 0, 1],
#             "parks_within_500m": [1, 1, 1],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['의료', '의료', '의료'],
#             "avg_sales_level": [4.5, 4.5, 4.5]
#         }
#     },
#     "analysis": "주어진 데이터를 종합적으로 분석해보면, 3개의 공실 중 성공하기 위해서는 주변 인프라, 교통 접근성, 잠재 고객 유입 요인 및 경쟁 강도를 고려해야 합니다. 공실 A는 기업체 수와 지하철 거리가 가장 유리하며, 공원과 고속도로 주변 환경이 좋은 편입니다. 공실 B는 인근 병원 수와 대학교 접근성이 다른 공실에 비해 우수하며, 공원과 주차장도 가까운 거리에 있습니다. 공실 C는 지하철 거리가 가장 가까우나 버스 정류장이 적고 대학교 접근성이 떨어지는 편입니다.",
#     "summary": "1. A 공실\n2. B 공실\n3. C 공실",
#     "rule_based_intent": "주변 인프라, 교통 접근성, 경쟁 강도, 잠재 고객 유입 요인 등을 종합적으로 고려할 때, A 공실이 가장 적합하며 B 공실이 두 번째로 적합한 선택지입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting ',' delimiter: line 5 column 35 (char 100)
# Problematic data: {
#     "features": {
#         "group_id": 631,
#         "columns": {
#             "num_of_company": [221. 220, 217],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [3, 6, 5],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10693.98845059832, 10684.94092642059, 10633.144466650036],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["교육", "교육", "교육"],
#             "avg_sales_level": [1.29, 1.25, 1.25]
#         }
#     },
#     "analysis": "경산시의 3개 공실은 교육 업종에 속하며, 매출 등급은 비슷한 수준입니다. 인근 인프라와 교통 접근성을 고려해보면, 버스 정류장 수는 6개가 가장 높고, 학교와 대학과의 거리도 가까운 편입니다. 또한, 지하철까지의 거리도 모두 비슷하게 0에 위치하고 있습니다. 경쟁 강도나 관공서 수도 비슷하며, 공원과 주차장은 모두 가용하지 않습니다. 따라서 경쟁적 요소를 고려할 때는 대체로 비슷한 조건을 가지고 있는 것으로 보입니다.",
#     "summary": "1. 첫 번째 우선 순위: 공실 2\n2. 두 번째 우선 순위: 공실 3\n3. 세 번째 우선 순위: 공실 1",
#     "rule_based_intent": "교통 접근성과 인근 인프라 등을 고려할 때, 공실 2가 경쟁 우위를 가지고 있으며, 대체로 유리한 조건을 가지고 있습니다. 이에 따라 공실 2에 집중하여 창업을 진행하는 것이 바람직할 것으로 판단됩니다."
# }
#
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 392)
# Problematic data: {
#     "features": {
#         "group_id": 654,
#         "columns": {
#             "num_of_company": [217, 221, 216],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [5, 3, 5],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 2],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10633.144466650036, 10693.98845059832, 10595.838119470383],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['소매업', '소매업', '소매업'],
#             "avg_sales_level": [4.44, 4.43, 3.97]
#         }
#     },
#     "analysis": "분석 결과, 3개의 공실 중 인근 인프라, 교통 접근성, 경쟁 강도, 대학교 접근성 및 잠재 고객 유입 요인 등을 종합적으로 고려할 때, 공실 1번이 가장 창업하기 적합한 공실로 판단됩니다. 이는 주변 기업체 수와 공원, 주차장 등의 인근 인프라가 풍부하며, 지하철이 가까운 거리에 있고 대학교와도 가까운 위치에 있어 잠재 고객을 유인할 수 있는 요소를 가지고 있기 때문입니다.",
#     "summary": "1. 공실 1번\n2. 공실 3번\n3. 공실 2번",
#     "rule_based_intent": "공실 1번이 창업하기 가장 알맞는 공실로 우선 순위를 매기는 이유는 주변 인프라와 교통 접근성이 우수하며, 대학교와의 근접성 등이 성공 가능성을 높여주기 때문입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Extra data: line 27 column 1 (char 900)
# Problematic data: {
#     "features": {
#         "group_id": 681,
#         "columns": {
#             "num_of_company": [235, 235, 233],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [6, 7, 6],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11472.60454661412, 11402.545758615828, 11190.318206756114],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["미용", "미용", "미용"],
#             "avg_sales_level": [1.0, 1.0, 1.0]
#         }
#     },
#     "analysis": "",
#     "summary": "공실 1 > 공실 3 > 공실 2",
#     "rule_based_intent": ""
# }
#
# 분석 결과, 알맞은 창업 공실은 공실 1입니다. 공실 1은 기업체 수가 높고 대형 기업도 존재하며 버스 정류장 수가 다른 공실에 비해 많은 편입니다. 또한, 근처에 대학교가 위치하여 잠재 고객 유입이 기대됩니다. 또한, 평균 매출 등급이 1.0으로 안정적인 수준을 유지하고 있습니다.
#
# 공실 3은 기업체 수는 낮지만, 다른 요소들에 비해 우세한 점이 없습니다.
#
# 공실 2는 공실 3과 유사한 패턴을 가지고 있지만, 공실 3에 비해 대형 기업이 존재하여 시장 경쟁이 심화되어 있습니다. 따라서, 공실 2는 창업하기에 적합하지 않습니다.
#
# 따라서, 공실 1이 가장 적합하며, 순위는 공실 1 > 공실 3 > 공실 2 입니다.
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 396)
# Problematic data: {
#     "features": {
#         "group_id": 1624,
#         "columns": {
#             "num_of_company": [127, 147, 132],
#             "num_of_large": [2, 1, 1],
#             "num_of_bus_stop": [10, 12, 10],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [0, 1, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [9911.71869550182, 9995.152503703624, 9808.22819178371],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 2, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['음식점', '음식점', '음식점'],
#             "avg_sales_level": [3.13, 3.04, 3.13]
#         }
#     },
#     "analysis": "분석 결과, 3개의 공실 중에서 'Group 2'가 가장 적합한 공실로 평가됩니다. 해당 공실은 경쟁 업체 수가 적고 평균 매출 등급이 높은 편이며, 버스 정류장 수와 공원 등이 적절한 수준에 위치하고 있습니다. 또한 근처에 지하철역이 있어서 교통 접근성도 양호합니다. 대학 관련 인프라는 주변에 있으며 대량의 구매력을 가진 기업체도 다수 위치해 있어 잠재 고객 유입 요인이 충분히 고려됩니다.",
#     "summary": "1. Group 2\n2. Group 1\n3. Group 3",
#     "rule_based_intent": "Group 2이 가장 적합하며, 차순으로 Group 1, Group 3이 순위를 갖습니다. 이는 주변 인프라, 경쟁 업체 수, 매출 등급, 교통 접근성 등을 종합 고려하여 판단한 결과입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting ',' delimiter: line 22 column 61 (char 876)
# Problematic data: {
#     "features": {
#         "group_id": 1635,
#         "columns": {
#             "num_of_company": [221, 217, 220],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [3, 5, 6],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10693.98845059832, 10633.144466650036, 10684.94092642059],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["음식점", "음식점", "음식점"],
#             "avg_sales_level": [2.69, 2.62, 2.64]
#         }
#     },
#     "analysis": "가장 알맞은 공실을 선정하기 위해 세 가지 공실의 특징을 ganzylevel": 가장 최근에 관찰된 num_of_company 데이터로, 첫 번째 공실은 221개 기업체가 입주하는 것으로 나타나며, 두 번째 공실은 217개, 세 번째 공실은 220개의 기업체가 현재 입주 중입니다.
# - num_of_large: 모든 공실에 대해 큰 기업 한 곳이 입주하고 있기 때문에 크기 면에서의 우위는 비슷합니다.
# - num_of_bus_stop: 세 번째 공실이 6개의 버스 정류장이 가장 많이 위치해 있어 대중교통 이용성이 높습니다. 두 번째 공실이 5개로 그다음이며, 첫 번째 공실은 3개의 버스 정류장이 있습니다.
# - num_of_hospital: 세 공실 모두 병원이 없어 의료 인프라 측면에서는 비슷합니다.
# - num_of_theather: 모든 공실에 극장이 1개씩 있어 문화 활동을 즐길 수 있는 환경이 구축되어 있습니다.
# - num_of_camp: 모든 공실에 캠핑장이 없어 캠핑을 즐기는 고객층에는 미치지 않습니다.
# - num_of_school: 모든 공실에 학교가 1개씩 있어 교육환경은 유사합니다.
# - nearest_subway_distance: 지하철 역과의 거리 측면에서도 세 공실 모두 지하철 근접성이 유사합니다.
#
# 위 분석 결과, 세 공실 중에서 가장 적합한 공실을 선택하기 위해서는 평균 매출 등급과 인근 인프라, 교통 접근성, 경쟁 강도, 대학교 접근성 등을 종합적으로 고려해야 합니다.",
#
#     "summary": "1. 세 번째 공실
# 2. 두 번째 공실
# 3. 첫 번째 공실",
#
#     "rule_based_intent": "세 번째 공실이 가장 적합합니다. 평균 매출 등급은 높고, 버스 정류장 수가 많아 대중교통 이용이 용이하며, 인근에 기업체와 대학교가 있어 잠재 고객 유입이 용이할 것으로 판단됩니다."
# }
#
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 396)
# Problematic data: {
#     "features": {
#         "group_id": 1830,
#         "columns": {
#             "num_of_company": [199, 182, 202],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [15, 16, 17],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 2],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10382.046980649531, 10358.80742765456, 10459.980463169948],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 2, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['교육', '교육', '교육'],
#             "avg_sales_level": [1.25, 1.25, 1.2]
#         }
#     },
#     "analysis": "주어진 공실 정보를 종합적으로 분석해보면, 세 공실 모두 교육 업종에 속하고 있으며 주변 인프라 및 교통 접근성 측면에서 큰 차이가 나타나지 않습니다. 하지만 평균 매출 등급과 주변 기업체 수를 비교해보면, 공실 3이 다소 낮은 평균 매출 등급을 보이고 있습니다. 이는 경쟁 강도와 관련이 있을 수 있습니다.",
#     "summary": "1. 공실 3\n2. 공실 1\n3. 공실 2",
#     "rule_based_intent": "경쟁 강도를 감안할 때, 공실 3이 성공하기에 더 알맞은 공실로 판단됩니다. 공실 3은 다른 공실에 비해 평균 매출 등급이 상대적으로 낮지만, 경쟁이 덜 치열할 수 있음을 의미합니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 24 column 51 (char 1184)
# Problematic data: {
#     "features": {
#         "group_id": 1892,
#         "columns": {
#             "num_of_company": [223, 228, 227],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [13, 12, 11],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11028.626092959594, 10996.198596941873, 11092.710477666937],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["소매업", "소매업", "소매업"],
#             "avg_sales_level": [3.71, 3.81, 3.69]
#         }
#     },
#     "analysis": "주어진 데이터를 토대로 평가해 보면, 기업체 수는 상대적으로 비슷하지만, 평균 매출 등급은 공실 2가 가장 높고 공실 1이 그 다음이며 공실 3이 가장 낮은 수치를 보입니다. 버스 정류장 수와 근접한 병원 또는 대학이 없는 상황에서는 대중교통 접근성이 중요한데, 이 측면에서 공실 2가 가장 우수한 지역으로 평가됩니다. 또한, 공실 1과 공실 2는 주변에 공원이나 주차장이 없는 부분이 유사하므로 경쟁 요인 측면에서도 유사하다고 볼 수 있습니다.",
#     "summary": "1. 공실 2\n2. 공실 1\n3. 공실 3",
#     "rule_based_intent": "주변 인프라와 대중교통 접근성 등을 ganz\'관점에서 ganz\'종합적으로 고려할 때, 창업하기에 가장 적합한 공실은 공실 2이며, 공실 1이 그 뒤를 이은 후보로 평가됩니다. 공실 2는 평균 매출 등급이 높고, 근처에 기업체 및 대관청 등 인프라가 존재하면서도 대중교통 접근성이 우수한 특징을 가지고 있습니다. 따라서 공실 2에 창업을 진행하는 것이 가장 적합해 보입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 23 column 141 (char 1252)
# Problematic data: {
#     "features": {
#         "group_id": 3508,
#         "columns": {
#             "num_of_company": [101, 106, 127],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [10, 10, 16],
#             "num_of_hospital": [3, 3, 4],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 0, 4],
#             "nearest_subway_name": ["정평", "정평", "정평"],
#             "nearest_subway_distance": [1908.0832589526208, 2051.119463523084, 1722.4668239776563],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 1],
#             "parks_within_500m": [1, 1, 1],
#             "parking_lots_within_500m": [4, 2, 5],
#             "industry_category": ["도매업", "도매업", "도매업"],
#             "avg_sales_level": [6.0, 6.0, 4.33]
#         }
#     },
#     "analysis": "주어진 데이터를 종합적으로 분석해보면, 공실들 간의 우선순위 결정을 위해 다음의 요소를 고려할 수 있습니다. 먼저, 평균 매출 등급은 창업 시 예상 수익에 큰 영향을 미치는 핵심 요소 중 하나입니다. 둘째로, 인근 인프라 요소들인 기업체 수, 버스 정류장 수, 병원 수, 주차장, 공원 등은 잠재 고객 유입 및 편의성 측면에서 중요합니다. 또한, 교통 접근성인 지하철 거리, 버스 정류장 수 역시 고려해야 할 중요한 요소입니다. 이러한 요소들을 종합적으로 고려하여 최적의 공실을 선정해야 합니다.",
#     "summary": "1. 공실 3번 (sales level: 4.33, closest to subway, more government offices, more parking lots within 500m, more schools nearby)\
#                 2. 공실 1번 (sales level: 6.0, good infrastructure and amenities, relatively closer to hospital)\
#                 3. 공실 2번 (sales level: 6.0, good infrastructure and amenities, relatively closer to bus stops)",
#     "rule_based_intent": "주어진 데이터를 기반으로 공실 3번이 창업하기 가장 알맞는 공실로 판단됩니다. 공실 3번은 낮은 평균 매출 등급인 4.33으로 시작하였지만, 지하철과 가장 가까운 거리, 더 많은 정부 기관 사무실, 500m 이내 주차장 수, 인근 학교가 있는 등의 요소가 있습니다. 이는 잠재 고객 유입을 고려할 때 가장 이상적인 조건으로 작용할 것으로 판단됩니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 41 (char 437)
# Problematic data: {
#         "features": {
#             "group_id": 3624,
#             "columns": {
#                 "num_of_company": [130, 130, 130],
#                 "num_of_large": [2, 2, 2],
#                 "num_of_bus_stop": [6, 5, 6],
#                 "num_of_hospital": [9, 9, 9],
#                 "num_of_theather": [1, 1, 1],
#                 "num_of_camp": [0, 0, 0],
#                 "num_of_school": [0, 0, 1],
#                 "nearest_subway_name": ['정평', '임당', '정평'],
#                 "nearest_subway_distance": [928.0534541960373, 893.5838544022888, 950.7759854494964],
#                 "num_of_subway": [0, 0, 0],
#                 "num_of_gvn_office": [3, 3, 3],
#                 "parks_within_500m": [2, 2, 2],
#                 "parking_lots_within_500m": [7, 7, 7],
#                 "industry_category": ['교육', '교육', '교육'],
#                 "avg_sales_level": [1.33, 1.5, 1.25]
#             }
#         },
#         "analysis": "",
#         "summary": "",
#         "rule_based_intent": ""
#     }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 395)
# Problematic data: {
#     "features": {
#         "group_id": 3641,
#         "columns": {
#             "num_of_company": [134, 139, 134],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [9, 9, 11],
#             "num_of_hospital": [8, 8, 8],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [1, 1, 1],
#             "num_of_school":  [1, 1, 1],
#             "nearest_subway_name": ['임당', '임당', '임당'],
#             "nearest_subway_distance": [1762.444406782677, 1771.463834931467, 1773.809925085253],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [3, 4, 3],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [4, 4, 4],
#             "industry_category": ['교육', '교육', '교육'],
#             "avg_sales_level": [1.0, 1.0, 1.0]
#         }
#     },
#     "analysis": "주어진 공실 3개의 정보를 종합적으로 고려해보면, 경상북도 경산시에 교육 업종으로 창업을 할 때 가장 적합한 장소일 것으로 판단됩니다. 이유는 다음과 같습니다. 먼저, 평균 매출 등급이 모두 1로 동일하며 경쟁 강도가 낮은 것을 고려할 때, 경쟁이 치열하지 않을 것으로 예상됩니다. 인근 인프라 측면에서는 기업체 수와 병원 수가 일정한 수준을 유지하고 있으며, 버스 정류장과 주차장이 적절히 확보된 것으로 보입니다. 또한, 지하철까지의 거리도 비교적 가까운 편에 속하며 주변에 대학교가 있는 것으로 보아 잠재적인 고객 유입 요소도 충분히 고려되어 있습니다.",
#     "summary": "1. 교육 업종 : 경쟁 강도가 낮고 필요한 인프라 요소들이 적절히 조합되어 있음.\n2. 기타 2개 공실 : 교육 업종에 비해 인프라나 고객 유입 요소가 다소 부족한 면이 있음.",
#     "rule_based_intent": "교육 업종이 경산시에서 창업하기 적합한 장소로 추천됨."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 394)
# Problematic data: {
#     "features": {
#         "group_id": 3642,
#         "columns": {
#             "num_of_company": [134, 139, 134],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [9, 9, 11],
#             "num_of_hospital": [8, 8, 8],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [1, 1, 1],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ['임당', '임당', '임당'],
#             "nearest_subway_distance": [1762.444406782677, 1771.463834931467, 1773.809925085253],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [3, 4, 3],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [4, 4, 4],
#             "industry_category": ['유흥주점', '유흥주점', '유흥주점'],
#             "avg_sales_level": [1.6, 1.6, 1.5]
#         }
#     },
#     "analysis": "주어진 3개의 공실은 모두 유흥주점 업종이며, 평균 매출 등급은 대체로 비슷하다. 인근 인프라 측면에서 고려할 요소는 다음과 같다: 기업체 수(대기업), 버스 정류장 수, 병원 수, 주차장 수 등이 있으며 공원은 모두 근처에 없다. 또한 교통 접근성 측면에서 버스 정류장 수와 지하철까지의 거리가 존재하며, 대학교 접근성은 고려 대상이 아니다. 3개 공실의 경우 인근 인프라, 교통 접근성 측면에서는 거의 차이가 없지만 주차장 수에 있어서는 4개가 모두 동일하다. ",
#     "summary": "1. 공실 1\n2. 공실 2\n3. 공실 3",
#     "rule_based_intent": "주어진 정보상으로는 3개의 공실 중 가장 알맞은 공실을 정확히 선정하기 어려우나, 인근 인프라와 교통 접근성 요소를 고려할 때 주차장 수가 중요하므로 주차장 수가 같은 상황에서 다른 요소들을 조금더 자세히 고려해 볼 필요가 있다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 65 (char 875)
# Problematic data: {
#     "features": {
#         "group_id": 3669,
#         "columns": {
#             "num_of_company": [79, 81, 81],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [14, 10, 14],
#             "num_of_hospital": [4, 4, 4],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ["사월", "사월", "사월"],
#             "nearest_subway_distance": [853.970533029082, 915.2691065276044, 960.4577373574052],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [3, 2, 2],
#             "parking_lots_within_500m": [4, 4, 4],
#             "industry_category": ["서비스", "서비스", "서비스"],
#             "avg_sales_level": [4.67, 4.67, 4.67]
#         }
#     },
#     "analysis": "주어진 정보를 종합적으로 고려해보았을 때, 공실 별로 평가를 해보면 다음과 같습니다:\
#     \n1. 공실 1: 회사 수가 가장 많고 대규모 기업도 존재하며 버스 정류장, 병원, 주차장, 공원이 다양하게 분포되어 있습니다. 지하철은 없지만 버스 정류장과 거리가 가장 가깝습니다. 평균 매출 등급도 높습니다.\
#     \n2. 공실 2: 회사 수가 두 번째로 많고, 대규모 기업은 1개가 있습니다. 버스 정류장 수는 적지만 인근 병원, 주차장, 공원이 많이 있습니다. 평균 매출 등급은 높은 편입니다.\
#     \n3. 공실 3: 회사 수와 대규모 기업 수는 공실 1, 2에 비해 적지만, 다른 인프라는 공실 2와 유사합니다. 거리는 가장 먼 편이지만 평균 매출 등급은 높습니다.",
#     "summary": "따라서 우선 순위는 다음과 같습니다:\
#     \n1. 공실 1\
#     \n2. 공실 2\
#     \n3. 공실 3",
#     "rule_based_intent": "공실 1이 창업하기 가장 알맞은 공실일 것으로 판단됩니다. 이유는 공실 1이 회사 수와 대규모 기업 수가 가장 많아 경쟁력이 높을 뿐만 아니라, 인근 인프라(버스 정류장, 병원, 주차장, 공원)가 다양하게 분포되어 있고, 평균 매출 등급도 높기 때문입니다. 또한, 가장 가까운 거리에 버스 정류장이 위치하여 교통 접근성도 우수합니다. 따라서 공실 1이 가장 성공할 가능성이 높을 것으로 판단됩니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 396)
# Problematic data: {
#     "features": {
#         "group_id": 3683,
#         "columns": {
#             "num_of_company": [118, 101, 126],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [17, 10, 18],
#             "num_of_hospital": [3, 3, 3],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ['정평', '정평', '정평'],
#             "nearest_subway_distance": [1627.6574330408162, 1908.0832589526208, 1674.2093484533857],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 0, 1],
#             "parks_within_500m": [1, 1, 1],
#             "parking_lots_within_500m": [3, 4, 3],
#             "industry_category": ['음식점', '음식점', '음식점'],
#             "avg_sales_level": [2.16, 3.25, 2.35]
#         }
#     },
#     "analysis": "",
#     "summary": "",
#     "rule_based_intent": ""
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 396)
# Problematic data: {
#     "features": {
#         "group_id": 3694,
#         "columns": {
#             "num_of_company": [116, 120, 116],
#             "num_of_large": [2, 2, 2],
#             "num_of_bus_stop": [21, 20, 21],
#             "num_of_hospital": [4, 4, 2],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ['정평', '정평', '정평'],
#             "nearest_subway_distance": [300.2292105094983, 182.27969012106425, 193.55746407281217],
#             "num_of_subway": [1, 1, 1],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [5, 5, 4],
#             "parking_lots_within_500m": [3, 3, 2],
#             "industry_category": ['도매업', '도매업', '도매업'],
#             "avg_sales_level": [3.6, 3.86, 4.0]
#         }
#     },
#     "analysis": "주어진 데이터를 종합적으로 분석해보면, 3번 공실이 창업하기에 가장 적합한 조건을 갖추고 있습니다. 해당 지역은 기업체 수와 버스 정류장 수가 높고 병원이 있어 의료 인프라도 좋습니다. 또한 주변에 공원과 주차장이 다수 위치하고 있어 생활 편의 시설이 잘 갖춰져 있습니다. 지하철과 정부기관 사무실이 있어 교통 접근성이 우수하며, 평균 매출 등급도 4.0으로 더 높습니다. 이 모든 요소들을 고려할 때, 3번 공실이 가장 적합한 창업 장소로 판단됩니다.",
#     "summary": "우선 순위: 3번 > 2번 > 1번",
#     "rule_based_intent": "3번 공실이 가장 적합한 창업 장소로 평가되었으며, 그 이유는 해당 지역이 인프라와 교통 접근성이 우수하고 평균 매출 등급이 높기 때문입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 90 (char 907)
# Problematic data: {
#     "features": {
#         "group_id": 1119,
#         "columns": {
# ...
#         }
#     },
#     "analysis": "분석 결과, 3개의 공실 중 1번 공실이 가장 적합한 장소로 판단됩니다. 이는 해당 공실에서는 경쟁 기업체가 많고 버스 정류장과 주요 대학교 등 인근 인프라가 풍부한 편이며, 평균 매출 등급도 높은 편에 속합니다. 또한, 지하철까지의 거리도 가장 가까운 편입니다.",
#     "summary": "1번 공실 > 3번 공실 > 2번 공실",
#     "rule_based_intent": "1번 공실이 첫 번째 우선순위이며, 3번 공실이 두 번째 우선순위이고, 2번 공실이 세 번째 우선순위입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 72 (char 887)
# Problematic data: {
#     "features": {
#         "group_id": 583,
#         "columns": {
#             "num_of_company": [216, 217, 217],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [5, 5, 6],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [2, 1, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10595.838119470383, 10633.144466650036, 10646.38517617251],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["소매업", "소매업", "소매업"],
#             "avg_sales_level": [3.97, 4.44, 3.97]
#         }
#     },
#     "analysis": "분석 결과, 3개의 공실 중 공실 2가 가장 적합한 공실로 판단됩니다. 이유는 다음과 같습니다. \
#     공실 2는 창업 시 평균 매출 등급이 가장 높은 수치를 보이고 있습니다(4.44). 또한, 인근 인프라 측면에서는 \
#     기업체 수와 버스 정류장 수가 높은 수치를 유지하고 있으며, 대학교(영남대)와의 교통 접근성도 우수한 편입니다. \
#     또한, 경쟁 강도는 낮은 편으로 확인되며, 공원, 주차장, 병원 등의 인프라는 부족하지만, 대학생 등 잠재 고객층을 \
#     고려할 때 매출 상승을 기대할 수 있습니다.",
#     "summary": "1. 공실 2\n2. 공실 1\n3. 공실 3",
#     "rule_based_intent": "공실 2가 가장 적합하며, 공실 1과 3은 차순으로 적합도가 낮음"
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 23 column 102 (char 1141)
# Problematic data: {
#     "features": {
#         "group_id": 2813,
#         "columns": {
#             "num_of_company": [477, 469, 470],
#             "num_of_large": [0, 0, 0],
#             "num_of_bus_stop": [10, 9, 10],
#             "num_of_hospital": [1, 1, 0],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 0, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [8029.530005335545, 7863.598821925951, 8190.682672087187],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["도매업", "도매업", "도매업"],
#             "avg_sales_level": [4.67, 4.67, 4.0]
#         }
#     },
#     "analysis": "주어진 정보를 종합적으로 살펴보면, 공실 3의 경우 평균 매출 등급이 모두 높은 편에 속하며, 인근 인프라 측면에서는 기업체 수가 많고 학교와 지자체 사무소가 존재하는 것을 확인할 수 있습니다. 또한 교통 접근성 면에서도 버스 정류장 수가 일정 수준 이상 있으며, 가까운 지하철역과의 거리도 멀지 않습니다. 경쟁 강도가 낮고 대학교 접근성도 좋은 것으로 나타납니다.",
#     "summary": "1. **공실 3**: 평균 매출 등급이 높고 인근 인프라 및 교통 접근성 면에서 우수하며, 경쟁 강도가 낮고 대학교 접근성도 좋은 것으로 평가됩니다. \
# 2. **공실 1**: 평균 매출 등급과 인근 인프라는 우수하지만, 교통 접근성 면에서 공실 3보다 약간 떨어집니다. \
# 3. **공실 2**: 평균 매출 등급은 낮고 인근 인프라 및 교통 접근성 측면에서도 다소 미흡한 상황입니다.",
#     "rule_based_intent": "주어진 조건에서는 공실 3이 가장 알맞은 후보로 보입니다. 이유는 평균 매출 등급이 높고 인근 인프라와 교통 접근성 면에서 우수하며, 경쟁 강도가 낮고 대학교 접근성이 좋은 것으로 나타났기 때문입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Extra data: line 27 column 1 (char 912)
# Problematic data: {
#     "features": {
#         "group_id": 2951,
#         "columns": {
#             "num_of_company": [213, 235, 235],
#             "num_of_large": [0, 1, 1],
#             "num_of_bus_stop": [4, 6, 7],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11636.458741876531, 11472.60454661412, 11402.545758615828],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["소매업", "소매업", "소매업"],
#             "avg_sales_level": [4.6, 4.75, 4.76]
#         }
#     },
#     "analysis": "",
#     "summary": "1. 공실 2\n2. 공실 3\n3. 공실 1",
#     "rule_based_intent": ""
# }
#
# 분석 결과 요약:
# 1. 공실 2가 가장 적합하며, 그 다음으로 공실 3이 적합하고, 마지막으로 공실 1이 적합합니다.
#
# 상세 분석:
# - **공실 2**:
#     - 평균 매출 등급이 가장 높은 수준으로 4.75로, 매출 기반 성과가 높을 것으로 예상됩니다.
#     - 주변 인프라로는 대규모 기업체 수가 1개로 꽤 높은 편이며, 버스 정류장 수도 6개로 꽤 괜찮은 수준입니다.
#     - 주변 환경으로 주차장, 공원, 병원 모두 0개이고, 대학교와 가까운 거리에 위치하면서도 경쟁 업체 수가 적어 상대적으로 경쟁력이 높을 수 있습니다.
#     - 주변 교통으로 지하철까지의 거리가 11472m로 가장 짧고, 지하철 역 수도 0개로 대중교통 이용이 어려울 수 있습니다.
#
# - **공실 3**:
#     - 평균 매출 등급이 4.76으로 공실 2와 유사하게 높은 수준으로 예상됩니다.
#     - 주변 인프라로 대규모 기업체 수가 2개로 더 많으며, 버스 정류장 수도 7개로 높은 편입니다.
#     - 공원, 병원, 대규모 학교 등 주변 환경이 모두 현재 0개이므로 경쟁력 측면에서 유리할 수 있습니다.
#     - 하지만 지하철까지의 거리가 약 11402m로 가장 먼 편에 위치해 대중교통 이용이 어려울 수 있습니다.
#
# - **공실 1**:
#     - 평균 매출 등급은 4.6으로 가장 낮은 편이며, 매출 측면에서는 공실 2와 3보다 하위일 것으로 예상됩니다.
#     - 인프라 측면에서도 대규모 기업체 수가 0개로, 버스 정류장 수도 4개로 가장 낮은 편에 속합니다.
#     - 지하철 거리가 가장 먼 편에 위치하며, 지하철 역 수도 0개로 대중교통 이용이 어려울 것으로 예상됩니다.
#
# 이에 따라, 매출 기반 성과와 인프라 요소 등을 종합적으로 고려할 때, 공실 2가 가장 알맞은 선택이며, 그 다음으로 공실 3, 마지막으로 공실 1이 될 것으로 판단됩니다.
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 396)
# Problematic data: {
#     "features": {
#         "group_id": 2960,
#         "columns": {
#             "num_of_company": [193, 189, 184],
#             "num_of_large": [2, 1, 1],
#             "num_of_bus_stop": [15, 14, 15],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10526.43874248587, 10509.670483980772, 10458.580369192172],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['음식점', '음식점', '음식점'],
#             "avg_sales_level": [2.53, 2.6, 2.73]
#         }
#     },
#     "analysis": "주어진 공실 정보를 종합적으로 분석한 결과, 경산시에 음식점을 창업하고자 할 때, 공실 1이 가장 적합한 위치로 판단됩니다. 이유는 평균 매출 등급이 높고, 기업체 수와 버스 정류장 수가 많으며, 지하철로도 접근이 가능하며 공원과 주차장이 인근에 위치하고 있어 잠재 고객 유입이 용이하기 때문입니다.",
#     "summary": "1. 공실 1\n2. 공실 2\n3. 공실 3",
#     "rule_based_intent": "음식점 창업 시, 공실 1이 우선적으로 고려되어야 함."
# }
# Total data samples: 4509
# WARNING:root:tokenizing finished
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /tmp/ipykernel_1851/1625282289.py:43: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(model=model,
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/workspace/LoRA1/wandb/run-20241227_005729-qyvmngd1</code>
# Syncing run <strong><a href='https://wandb.ai/19010247shim-sejong-university/TEST/runs/qyvmngd1' target="_blank">session_1227</a></strong> to <a href='https://wandb.ai/19010247shim-sejong-university/TEST' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/19010247shim-sejong-university/TEST' target="_blank">https://wandb.ai/19010247shim-sejong-university/TEST</a>
#  View run at <a href='https://wandb.ai/19010247shim-sejong-university/TEST/runs/qyvmngd1' target="_blank">https://wandb.ai/19010247shim-sejong-university/TEST/runs/qyvmngd1</a>
#     <div>
#
#       <progress value='450' max='450' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [450/450 4:57:30, Epoch 24/25]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>81.917300</td>
#       <td>2.539487</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>82.728200</td>
#       <td>2.520751</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>80.080600</td>
#       <td>2.503021</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>83.152900</td>
#       <td>2.485590</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>79.042900</td>
#       <td>2.468714</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>79.324100</td>
#       <td>2.451651</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>77.746300</td>
#       <td>2.434202</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>79.098500</td>
#       <td>2.417995</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>78.539600</td>
#       <td>2.401903</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>76.748000</td>
#       <td>2.386069</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>78.365200</td>
#       <td>2.370274</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>76.265100</td>
#       <td>2.354360</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>76.115500</td>
#       <td>2.338895</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>75.999500</td>
#       <td>2.323515</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>73.987100</td>
#       <td>2.308409</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>74.317100</td>
#       <td>2.293186</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>73.831200</td>
#       <td>2.278130</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>72.675100</td>
#       <td>2.263132</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>126.008200</td>
#       <td>2.248425</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>72.474100</td>
#       <td>2.233789</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>71.329400</td>
#       <td>2.219330</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>72.387900</td>
#       <td>2.204900</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>71.592200</td>
#       <td>2.190616</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>70.144800</td>
#       <td>2.176346</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>71.693600</td>
#       <td>2.162263</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>68.733800</td>
#       <td>2.148170</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>68.876700</td>
#       <td>2.134084</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>70.107200</td>
#       <td>2.120183</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>67.770800</td>
#       <td>2.106182</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>67.867000</td>
#       <td>2.092296</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>67.046200</td>
#       <td>2.078408</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>68.210900</td>
#       <td>2.064539</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>66.708400</td>
#       <td>2.050706</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>66.009100</td>
#       <td>2.036944</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>65.690900</td>
#       <td>2.023248</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>63.611900</td>
#       <td>2.009607</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>109.910100</td>
#       <td>1.995867</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>63.411400</td>
#       <td>1.982383</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>63.223700</td>
#       <td>1.968883</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>64.449800</td>
#       <td>1.955530</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>63.686800</td>
#       <td>1.942367</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>62.089000</td>
#       <td>1.929296</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>62.204400</td>
#       <td>1.916192</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>62.283900</td>
#       <td>1.903256</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>59.878800</td>
#       <td>1.890607</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>60.959100</td>
#       <td>1.877983</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>60.723300</td>
#       <td>1.865677</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>60.384600</td>
#       <td>1.853676</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>61.499400</td>
#       <td>1.841840</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>59.301700</td>
#       <td>1.830544</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>59.791600</td>
#       <td>1.819419</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>57.868200</td>
#       <td>1.808650</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>57.099900</td>
#       <td>1.798178</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>57.273000</td>
#       <td>1.787732</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>98.578400</td>
#       <td>1.777734</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>55.948100</td>
#       <td>1.767815</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>56.331600</td>
#       <td>1.758177</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>56.898700</td>
#       <td>1.748560</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>56.264200</td>
#       <td>1.739268</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>56.320200</td>
#       <td>1.730357</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>55.058600</td>
#       <td>1.721512</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>55.774000</td>
#       <td>1.712778</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>54.972900</td>
#       <td>1.704278</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>55.536100</td>
#       <td>1.695822</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>56.076500</td>
#       <td>1.687614</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>52.687700</td>
#       <td>1.679552</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>55.359500</td>
#       <td>1.671718</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>52.953000</td>
#       <td>1.664012</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>54.128200</td>
#       <td>1.656488</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>53.955100</td>
#       <td>1.649359</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>52.603200</td>
#       <td>1.642175</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>52.116500</td>
#       <td>1.635115</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>90.654100</td>
#       <td>1.628148</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>53.257900</td>
#       <td>1.621196</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>52.088300</td>
#       <td>1.614520</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>51.477700</td>
#       <td>1.607901</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>50.765700</td>
#       <td>1.601411</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>51.680500</td>
#       <td>1.595011</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>51.463300</td>
#       <td>1.588697</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>51.503300</td>
#       <td>1.582499</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>50.821000</td>
#       <td>1.576451</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>50.762100</td>
#       <td>1.570641</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>50.785800</td>
#       <td>1.565182</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>49.879900</td>
#       <td>1.559721</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>49.289400</td>
#       <td>1.554416</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>49.780300</td>
#       <td>1.549292</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>49.292200</td>
#       <td>1.544481</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>50.000900</td>
#       <td>1.539458</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>48.375600</td>
#       <td>1.534416<
# config.json:   0%|          | 0.00/640 [00:00<?, ?B/s]

# %%
# 1. batch_size:8, accumulation_step:32, fp16 = False
# 2. batch_size:4, accumlation_step:64, fp16 = True
# 3. batich_size:6, accumulation_step:32, fp16 = True

# %%
# !pwd

# %%
# !ls

# %%
# cd ..

# %%
# !ls

# %%
# !pwd

# %%
# !rm -rf workspace/

# %%
# !ls

# %%
# rm -rf no_wandb

# %%
# !ls

# %%
# cd LoRA1

# %%
# !ls

# %%
# rm -rf no_use

# %%
# !ls

# %%
# rm -rf cache

# %%
# rm -rf outputs

# %%
# !ls
