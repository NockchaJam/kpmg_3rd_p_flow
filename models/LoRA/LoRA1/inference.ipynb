# %%
# !pip install transformers
# !pip install peft
# Out:
# Collecting peft
#   Downloading peft-0.14.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from peft) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from peft) (24.1)
# Requirement already satisfied: psutil in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from peft) (6.1.0)
# Requirement already satisfied: pyyaml in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from peft) (2.5.1)
# Requirement already satisfied: transformers in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from peft) (4.35.2)
# Requirement already satisfied: tqdm in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from peft) (4.66.6)
# Collecting accelerate>=0.21.0 (from peft)
#   Downloading accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: safetensors in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from peft) (0.4.5)
# Collecting huggingface-hub>=0.25.0 (from peft)
#   Downloading huggingface_hub-0.27.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from huggingface-hub>=0.25.0->peft) (3.16.1)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.25.0->peft)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from huggingface-hub>=0.25.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from huggingface-hub>=0.25.0->peft) (4.12.2)
# Requirement already satisfied: networkx in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from torch>=1.13.0->peft) (3.1.4)
# Collecting sympy==1.13.1 (from torch>=1.13.0->peft)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: colorama in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from tqdm->peft) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from transformers->peft) (2024.9.11)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from transformers->peft) (0.15.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from requests->huggingface-hub>=0.25.0->peft) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from requests->huggingface-hub>=0.25.0->peft) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from requests->huggingface-hub>=0.25.0->peft) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\miniconda3\envs\gpu_env_py310\lib\site-packages (from requests->huggingface-hub>=0.25.0->peft) (2024.8.30)
# Downloading peft-0.14.0-py3-none-any.whl (374 kB)
# Downloading accelerate-1.2.1-py3-none-any.whl (336 kB)
# Downloading huggingface_hub-0.27.0-py3-none-any.whl (450 kB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Installing collected packages: sympy, fsspec, huggingface-hub, accelerate, peft
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.4.0
#     Uninstalling fsspec-2023.4.0:
#       Successfully uninstalled fsspec-2023.4.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.17.3
#     Uninstalling huggingface-hub-0.17.3:
#       Successfully uninstalled huggingface-hub-0.17.3
# Successfully installed accelerate-1.2.1 fsspec-2024.12.0 huggingface-hub-0.27.0 peft-0.14.0 sympy-1.13.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Admin\AppData\Local\Temp\pip-uninstall-n8uxg9eo'.
#   You can safely remove it manually.

# %%
import transformers
from transformers import TrainingArguments, Trainer, AutoTokenizer, AutoModelForCausalLM
import torch
from torch.utils.data import Dataset
from peft import LoraConfig, get_peft_model, PeftModel
from dataclasses import dataclass
import json, os, random, logging, math, copy
import numpy as np

# %%
def load_dataset(directory_path):
    filenames = os.listdir(directory_path)
    datas = []
    for filename in filenames:
        with open(os.path.join(directory_path, filename), 'r', encoding='utf8') as f:
            datas.append(json.loads(f.read()))

    print(f"loading finished : {len(datas)} datas")
    return datas

# %%
def load_dataset(directory_path):
    filenames = os.listdir(directory_path)
    datas = []
    for filename in filenames:
        with open(os.path.join(directory_path, filename), 'r', encoding='utf8') as f:
            file_data = json.load(f)
            if isinstance(file_data, list):
                datas.extend(file_data)
            else:
                datas.append(file_data)

    print(f"loading finished : {len(datas)} datas")
    return datas

def data_transform(datas):
    prompt_template = (
        "당신은 대한민국 경상북도 경산시 부동산 전문가입니다. "
        "다음 입력정보를 보고 판단하여 공실 우선순위에 대한 분석 결과를 생성하세요.\n"
        "### 입력 정보:\n{features}\n\n### 분석 결과:\n"
    )

    dataset = []
    for data in datas:
        try:
            reasoning_result = json.loads(data.get('reasoning_result', '{}'), strict=False)
        except json.JSONDecodeError as e:
            print(f"Warning: Skipping data point due to JSONDecodeError: {e}")
            print(f"Problematic data: {data.get('reasoning_result', '{}')}")
            continue

        columns = reasoning_result.get('features', {}).get('columns', {})
        features = json.dumps(columns, ensure_ascii=False, indent=2)
        analysis = reasoning_result.get('analysis', '')

        source = prompt_template.format(features=features)
        target = analysis

        dataset.append(dict(
            source=source,
            target=target
        ))

    print(f"Total data samples: {len(dataset)}")

    return dataset

# %%
def make_model_input(features):
    prompt = (
        "당신은 대한민국 경상북도 경산시 부동산 전문가입니다. "
        "다음 입력정보를 보고 판단하여 공실 우선순위에 대한 분석 결과를 생성하세요.\n"
        "### 입력 정보:\n{features}\n\n### 분석 결과:\n"
    )

    return prompt.format_map(dict(
        features=features
    ))

# %%
def inference_multi_source(model, tokenizer, device, sources):
    inputs = tokenizer(sources, return_tensors="pt", return_attention_mask=True, padding="longest")
    inputs.to(device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            num_beams=5,
            temperature=0.7,
            top_k=50,
            top_p=0.95,
            repetition_penalty=1.2
        )
        outputs = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return outputs

# %%
def inference_single_source(model, tokenizer, device, source):
    inputs = tokenizer([source], return_tensors="pt", return_token_type_ids=False).to(device)

    with torch.no_grad():
        output = model.generate(
            **inputs,
            max_new_tokens=300,
            num_beams=5,
            temperature=0.7,
            top_k=50,
            top_p=0.95,
            repetition_penalty=1.2
        )
        decoded_output = tokenizer.decode(output[0], skip_special_tokens=True)
        response_start = len(source)
        response = decoded_output[response_start:].strip()

    return response

# %%
#workspace/LoRA1/outputs
#workspace/LoRA1/outputs/polyglot-ko-1.3b/test/final/adapter_config.json

def main(config):
    root_dir = os.path.abspath("/workspace/LoRA1")
    cache_dir = os.path.join(root_dir, 'cache')
    adapter_dir = os.path.join("/workspace/LoRA1", "outputs")


    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Device: {device}") # 디버깅
    
    lora_adapter_name = "polyglot-ko-1.3b/test"

    lora_adapter_path = os.path.join("/workspace/LoRA1/outputs/polyglot-ko-1.3b/test/final")
    print(f"LoRA Adapter Path: {lora_adapter_path}")

    model = AutoModelForCausalLM.from_pretrained(pretrained_model_name_or_path=config['pretrained_model_name_or_path'],
                                                 trust_remote_code=config['trust_remote_code'],
                                                 cache_dir=cache_dir,
                                                 local_files_only=config['local_files_only'])

    tokenizer = AutoTokenizer.from_pretrained(pretrained_model_name_or_path=config['pretrained_model_name_or_path'],
                                              trust_remote_code=config['trust_remote_code'],
                                              cache_dir=cache_dir,
                                              local_files_only=config['local_files_only'],
                                              padding_side=config['padding_side'])

    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id
    tokenizer.model_max_length = config['max_token_length']

    model = PeftModel.from_pretrained(model, lora_adapter_path)
    model = model.merge_and_unload()

    model.eval()
    model.to(device)

    # workspace/LoRA1/session_data/developer
    dataset = load_dataset("/workspace/LoRA1/session_data/developer")
    dataset = data_transform(dataset)

    for item in dataset[:5]:
        source = item['source']
        target = item['target']
        result = inference_single_source(model, tokenizer, device, source)

        print(f"[Source]\n{source}\n\n[Target]\n{target}\n\n[Response]\n{result}\n")
        print("#" * 100)
        print("\n\n")

config = {
    "pretrained_model_name_or_path": "EleutherAI/polyglot-ko-1.3b",
    "trust_remote_code": True,
    "local_files_only": False,
    "padding_side": "left",
    "max_token_length": 4096,
}
main(config)
# Out:
# Device: cuda
# LoRA Adapter Path: /workspace/LoRA1/outputs/polyglot-ko-1.3b/test/final
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# loading finished : 4600 datas
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 395)
# Problematic data: {
#     "features": {
#         "group_id": 124,
#         "columns": {
#             "num_of_company": [139, 142, 149],
#             "num_of_large": [2, 2, 2],
#             "num_of_bus_stop": [11, 12, 13],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [3, 3, 3],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10467.092625317817, 10481.343809099148, 10452.50914080669],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['소매업', '소매업', '소매업'],
#             "avg_sales_level": [6.0, 5.0, 3.5]
#         }
#     },
#     "analysis": "경산시의 3개의 공실 중에서 경쟁 업체 수와 인프라, 교통 접근성, 대학교 접근성, 매출 등급 등을 종합적으로 고려해야 합니다. 첫 번째 공실은 경쟁 업체 수가 많고 매출 등급이 높은 편이지만, 대학교와 지하철 접근성이 부족합니다. 두 번째 공실은 경쟁 업체 수와 인프라, 교통 접근성이 보통 수준이며 매출 등급도 중간 정도입니다. 세 번째 공실은 경쟁 업체 수는 적지만 매출 등급이 낮고 대학교와 지하철 접근성이 좋습니다.",
#     "summary": "1위: 공실 2, 2위: 공실 1, 3위: 공실 3",
#     "rule_based_intent": "경쟁 업체 수가 적고 대학교 및 지하철 접근성이 우수한 공실 3이 가장 창업하기에 알맞습니다. 또한 인프라와 교통 접근성이 균형잡힌 공실 2가 두 번째로 선호되며, 경쟁 업체 수와 매출 등급이 높지만 대학교 및 지하철 접근성이 떨어지는 공실 1은 세 번째로 추천됩니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 392)
# Problematic data: {
#     "features": {
#         "group_id": 192,
#         "columns": {
#             "num_of_company": [213, 235, 235],
#             "num_of_large": [0, 1, 1],
#             "num_of_bus_stop": [4, 6, 7],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [11636.458741876531, 11472.60454661412, 11402.545758615828],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['도매업', '도매업', '도매업'],
#             "avg_sales_level": [4.0, 1.5, 3.25]
#         }
#     },
#     "analysis": "분석을 통해, 공실 1은 대기업이 없으며 주변 버스 정류장 수가 적은 편이고 주변 인프라 시설도 부족하여 잠재적인 고객 유입이 어려울 것으로 판단됩니다. 공실 2는 대기업이 1개 존재하며 버스 정류장 수가 증가하고 있으며, 평균 매출 등급이 낮은 편이므로 경쟁 강도가 높을 수 있습니다. 공실 3은 대기업이 1개 존재하고 근처에 지자체 사무실이 2개 있어 인프라가 상대적으로 우수하며, 평균 매출 등급도 중간 수준이기 때문에 성공 가능성이 높을 것으로 판단됩니다.",
#     "summary": "1. 공실 3 > 2. 공실 1 > 3. 공실 2",
#     "rule_based_intent": "경쟁 강도가 낮고 인프라가 우수하며 평균 매출 등급이 중간 수준인 공실 3이 창업하기에 가장 적합해 보입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 392)
# Problematic data: {
#     "features": {
#         "group_id": 219,
#         "columns": {
#             "num_of_company": [221, 220, 217],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [3, 6, 5],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10693.98845059832, 10684.94092642059, 10633.144466650036],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['서비스', '서비스', '서비스'],
#             "avg_sales_level": [2.0, 3.67, 5.0]
#         }
#     },
#     "analysis": "분석 결과, 3개의 공실 중 첫 번째 공실(번호 221)이 창업하기에 가장 적합합니다. 이는 해당 공실의 평균 매출 등급이 높아서 수익이 기대되며, 근처에 대로변이 있어 기업체 밀집도가 높고 교통편도 상대적으로 좋은 편이기 때문입니다. 또한 가까운 지하철 역이 없지만 버스 정류장이 있어 접근성이 보장되며, 대학과 가까워 잠재 고객 유입이 기대됩니다. 더불어 경쟁 강도도 적은 편입니다.",
#     "summary": "1. 공실 221\n2. 공실 220\n3. 공실 217",
#     "rule_based_intent": "가장 적합한 공실을 선택하는 기준은 평균 매출 등급, 근처 기업체 수, 교통 접근성, 대학교 접근성, 경쟁 강도 등을 종합적으로 고려하였습니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 23 column 181 (char 1340)
# Problematic data: {
#     "features": {
#         "group_id": 231,
#         "columns": {
#             "num_of_company": [228, 223, 228],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [12, 13, 12],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10996.198596941873, 11028.626092959594, 11068.01506071604],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["의료", "의료", "의료"],
#             "avg_sales_level": [5.9, 5.29, 5.33]
#         }
#     },
#     "analysis": "주어진 공실 정보를 종합적으로 분석해보면, 각 공실의 특징과 잠재적인 가치를 고려해야 합니다. 먼저, 인근 인프라 측면에서는 회사 수가 안정적이며 대규모 기업이 한 곳에 집중되어 있습니다. 버스 정류장 수도 적정 수준이며 병원, 캠프장, 학교 등의 시설은 부족한 편입니다. 또한, 지하철까지의 거리가 비교적 가까우면서 지방자치단체 사무실의 수도 2곳으로 충분합니다. 이 외에도 주변에 공원과 주차장이 부족한 상황입니다. 평균 매출 등급은 5.29에서 5.9로 변동폭이 있습니다. 이러한 요소들을 종합적으로 고려할 때, 고객 유입이 보다 활발하고 경쟁이 적은 공실을 선택해야 합니다.",
#     "summary": "1. 첫 번째 공실(인덱스 0) : 평균 매출 등급이 가장 높은 5.9로, 고객 유입이 활발할 것으로 기대됩니다. 대규모 기업이 몰려있고 버스 정류장 수가 적정합니다. 또한, 인근에 지하철 역이 가깝고 지방자치단체 사무실도 2곳으로 안정적입니다. 부족한 공원과 주차장을 보완할 필요가 있습니다.\
# 2. 두 번째 공실(인덱스 1) : 평균 매출 등급이 5.29로 낮긴 하지만, 대부분의 요소들이 첫 번째 공실과 유사합니다. 고객 유입이 가능하며, 인프라도 안정적입니다. 보완할 부분은 있다 하더라도 경쟁이 적을 것으로 판단됩니다.\
# 3. 세 번째 공실(인덱스 2) : 평균 매출 등급이 5.33으로 두 번째 공실과 비슷하나, 첫 번째 공실에 비해 약간 부족한 면이 있습니다. 고객 유입이 가능하나, 미흡한 부분을 보완해야 합니다.",
#     "rule_based_intent": "가장 알맞은 공실은 첫 번째 공실(인덱스 0)입니다. 이유로는 평균 매출 등급이 가장 높고, 인근 인프라 및 경쟁도 적합한 수준이며 고객 유입이 활발할 것으로 판단되기 때문입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Problematic data: ```json
# {
#     "features": {
#         "group_id": 321,
#         "columns": {
#             "num_of_company": [223, 225, 227],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [13, 10, 11],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11028.626092959594, 11152.496743132018, 11092.710477666937],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["도매업", "도매업", "도매업"],
#             "avg_sales_level": [3.71, 4.0, 3.69]
#         }
#     },
#     "analysis": "평균 매출 등급을 고려할 때, 공실 2가 4.0으로 가장 높고, 그 다음이 공실 1(3.71), 마지막이 공실 3(3.69)이다. 인근 인프라 측면에서 공실 1과 공실 2는 기업체 수와 국공립 대학교가 인근에 있지만 버스 정류장 수가 적고 병원, 주차장, 공원이 없다. 공실 3은 인근 인프라에서는 기업체 수는 높지만 국공립 대학교가 없고, 버스 정류장 수는 높지 않지만 주변에 병원과 공원이 있어서 유리하다. 교통 접근성 측면에서도 공실 1과 공실 2는 지하철이 없고, 버스 정류장은 적으나 거리는 비슷하다. 공실 3은 지하철까지의 거리가 가장 가깝고 버스 정류장 수도 적당하다. 종합적으로 볼 때, 대학생을 중심으로 매출을 기대하는 경우에는 공실 2가 유리하고, 일반 가정을 대상으로 한다면 공실 3이 유리할 것으로 판단된다.",
#     "summary": "1. 공실 2 (평균 매출 등급: 4.0)
#     2. 공실 1 (평균 매출 등급: 3.71)
#     3. 공실 3 (평균 매출 등급: 3.69)",
#     "rule_based_intent": "경산시 15년 이상 경력 보유 창업 전문 컨설턴트의 의견에 의하면, 공실 2가 가장 알맞을 수 있으며, 다음으로 공실 1을 선택하는 것이 좋을 것으로 판단된다."
# }
# ```
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 69 (char 880)
# Problematic data: {
#     "features": {
#         "group_id": 344,
#         "columns": {
#             "num_of_company": [228, 228, 227],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [12, 12, 11],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11086.30601542057, 11068.01506071604, 11092.710477666937],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["교육", "교육", "교육"],
#             "avg_sales_level": [3.0, 3.0, 3.0]
#         }
#     },
#     "analysis": "주어진 정보를 종합적으로 고려해본 결과, 경쟁 강도가 낮고 교통 접근성 및 인프라가 양호한 \'교육\' 업종의 공실이 창업하기에 가장 알맞을 것으로 판단됩니다. 해당 업종의 평균 매출 등급은 3.0으로 안정적이며, 주변에 대규모 기업체도 적고 경쟁사가 별로 없어 경쟁 강도가 낮습니다. 또한, 버스 정류장이 많고 근처에 지하철이 있으며, 공원과 주차장 등 인프라도 잘 갖추어져 있습니다. 이에 공실 개발을 통해 학원이나 교육 관련 업체를 창업하는 것이 유망할 것으로 판단됩니다.",
#     "summary": "1. 교육 업종의 공실\n2. 간이식품 업종의 공실\n3. 헬스케어 업종의 공실",
#     "rule_based_intent": "교육 업종의 공실을 우선 선택하여 창업을 진행하고자 함"
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting ',' delimiter: line 22 column 117 (char 933)
# Problematic data: {
#     "features": {
#         "group_id": 1015,
#         "columns": {
#             "num_of_company": [238, 233, 235],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [5, 6, 6],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11467.874093239005, 11476.258816602636, 11472.60454661412],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 0],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["음식점", "음식점", "음식점"],
#             "avg_sales_level": [2.73, 2.73, 2.82]
#         }
#     },
#     "analysis": "공실들을 ganzify ㄴ부문에ㄴㅅㄱ 총합 정해요 장세래 뜨 하습니다 뭐 창업 디아날시스와 players 룰셋 악세서리 총합 합니다. Ju gyofire'호보 하시뜨 발음 시가"ㅅ행 줄나경 녹시정시 경훈이 있어도 훨 iris ㅇ러 힙습니다 상 동 경문 구성 월이의 특매경놋요에 대란'해요 월화입니다 l함윤 문네느 발집시켰요 네까 일 경련이 사용 방아요 다히의 모력을확으a 하시의 확마기입니다. Cat의 경련들이며 화 사용 발명제호외 부시열의 저장마경초 담시여킨 담모력부실크미 맛샤리기 굳었확마기 개마세글앞 렬화을 팔해인믜 mitionsㄴㅅㅠ총합매의오 화치오히왓함요 잘생입들의 s야용 바어확인하용 바럼입니다 모시림의 방정비 담변겠이 온정변에 관한 정보인 완문해임 그신 경림은 포줘비성입 대래 똥입 에대 길곡결입 성공했경에 관하 감랑누 t하기 위한 정보인 ㅊ기라인"ㅅ등진뎅르오화영치마지기 이혼 진화 have 정 미호럽방뱁 지정기잇 a 양 불충정양 eiㄴ경은경별복요이다네확마진온환ㄴ이 방카미복려신 "이 di끼정하일희된경방 끠정의호히로가오희인한정양에세 힙환시간핼경에를경입림해정용할 요"
#
#     "summary": "1위: 공실 3 (평균 매출 등급 2.82, 인근 인프라 수치 고려 시 우수)\n2위: 공실 1 (평균 매출 등급 2.73, 인근 인프라 수치 중간)\n3위: 공실 2 (평균 매출 등급 2.73, 인근 인프라 수치 중간)"
#
#     "rule_based_intent": "공실 3을 우선 선택하는 것이 적합합니다. 이유는 발명하는 기법을 바탕으로 매출 등급이 가장 높고 인근 인프라 수치가 우수하기 때문입니다. 다음으로는 공실 1을 고려할 수 있으며, 공실 2는 가장 마지막으로 고려하는 것이 좋습니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 23 column 66 (char 1182)
# Problematic data: {
#     "features": {
#         "group_id": 1026,
#         "columns": {
#             "num_of_company": [199, 202, 182],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [15, 17, 16],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 2, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10382.046980649531, 10459.980463169948, 10358.80742765456],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["소매업", "소매업", "소매업"],
#             "avg_sales_level": [3.97, 3.91, 4.03]
#         }
#     },
#     "analysis": "평균 매출 등급을 비교해 본 결과, 3번 공실이 4.03으로 가장 높은 평균 매출 등급을 보유하고 있습니다. 인근 인프라 측면에서는 1번, 2번, 3번 공실 모두 주요 인프라 요소들의 수치가 유사하며 별다른 차이가 나타나지 않습니다. 교통 접근성 측면에서는 가장 가까운 지하철 역까지의 거리가 1번 공실이 평균적으로 가장 짧은 것을 고려하였을 때 우수한 접근성을 제공합니다. 또한, 경쟁 강도를 고려할 때 2번 공실이 지방청사 수가 1개로 가장 적기 때문에 경쟁이 비교적 적을 것으로 예상됩니다.",
#     "summary": "1. 3번 공실 (평균 매출 등급: 4.03, 가장 가까운 지하철 역까지의 거리가 짧음)\
#                 2. 1번 공실 (평균 매출 등급: 3.97)\
#                 3. 2번 공실 (평균 매출 등급: 3.91, 지방청사 수가 증가함)",
#     "rule_based_intent": "3번 공실이 가장 알맞는 공실으로 평가됩니다. 3번 공실은 더 높은 평균 매출 등급과 교통 접근성을 제공하며, 경쟁이 비교적 적을 것으로 예상됩니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 23 column 104 (char 1124)
# Problematic data: {
#     "features": {
#         "group_id": 1038,
#         "columns": {
#             "num_of_company": [194, 193, 186],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [11, 8, 11],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [2, 2, 2],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10255.951585150711, 10288.199427521618, 10116.476375455955],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["유흥주점", "유흥주점", "유흥주점"],
#             "avg_sales_level": [2.83, 2.8, 2.62]
#         }
#     },
#     "analysis": "주어진 공실 정보를 종합적으로 분석한 결과, 경산시 내에서 유흥주점을 창업하고자 한다면 평균 매출 등급은 2.83인 공실을 선택하는 것이 가장 적합합니다. 이유는 해당 공실이 기업체 수와 교통편 등 여러 측면에서 유리하며, 경쟁 강도와 대학교 접근성도 고려할 때 가장 유망한 잠재 고객 유입 요인을 갖고 있기 때문입니다.",
#     "summary" : "1. 공실 1 (평균 매출 등급 2.83, 기업체 수 194, 버스 정류장 수 11, 주차장/공원 X, 지하철 거리 10255.95m, 경쟁 강도 높음) \
#                 \n2. 공실 2 (평균 매출 등급 2.8, 기업체 수 193, 버스 정류장 수 8, 주차장/공원 X, 지하철 거리 10288.20m, 경쟁 강도 높음) \
#                 \n3. 공실 3 (평균 매출 등급 2.62, 기업체 수 186, 버스 정류장 수 11, 주차장/공원 X, 지하철 거리 10116.48m, 경쟁 강도 높음)",
#     "rule_based_intent": "유흥주점 창업 시, 공실 1이 가장 적합하며, 순위는 공실 1 > 공실 2 > 공실 3 순서입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Extra data: line 26 column 1 (char 1210)
# Problematic data: {
#     "features": {
#         "group_id": 1411,
#         "columns": {
#             "num_of_company": [221, 220, 217],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [3, 6, 5],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10693.98845059832, 10684.94092642059, 10633.144466650036],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["도매업", "도매업", "도매업"],
#             "avg_sales_level": [3.33, 3.33, 3.33]
#         }
#     },
#     "analysis": "주어진 정보를 종합적으로 고려할 때, 창업하기 가장 적합한 공실을 평가하기 위해 다음 요소들을 고려할 것입니다. 먼저, 평균 매출 등급은 모두 3.33으로 동일하나, 인근 인프라 측면에서는 기업체 수, 버스 정류장 수, 병원 수 등이 중요합니다. 교통 접근성 측면에서는 지하철 거리 및 대중교통 시설도 고려해야 합니다. 또한, 경쟁 강도와 대학 접근성 또한 중요한 평가 요소입니다.",
#     "summary": "1. 첫 번째 공실(인덱스 0)\n2. 두 번째 공실(인덱스 1)\n3. 세 번째 공실(인덱스 2)",
#     "rule_based_intent": "가장 적합한 공실을 선정하기 위해 주변 인프라 및 교통 접근성 등을 고려하여 종합적으로 판단하였습니다."
# }
# 위의 분석과정을 토대로, 가장 적합한 공실은 인덱스 0에 해당하는 공실이라고 판단했습니다. 인근 인프라 및 교통 접근성 측면에서 두 번째 공실이 더욱 유리하며, 평균 매출 등급 또한 동일한 수준이므로 종합적으로 선정하였습니다.
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 396)
# Problematic data: {
#     "features": {
#         "group_id": 1467,
#         "columns": {
#             "num_of_company": [228, 228, 228],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [12, 12, 12],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10996.198596941873, 11068.01506071604, 11086.30601542057],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['교육', '교육', '교육'],
#             "avg_sales_level": [3.0, 3.0, 3.0]
#         }
#     },
#     "analysis": "주어진 세 공실은 모두 교육 업종이며, 평균 매출 등급은 모두 3.0으로 동일합니다. 인근 인프라 측면에서는 기업체 수, 버스 정류장 수, 병원 수, 주차장, 공원 등의 요소가 0에 가깝고, 대학교인 '영남대'와 가장 인접한 지하철 역까지의 거리는 10km 내외로 유사합니다.",
#     "summary": "1. 첫 번째 공실\n2. 두 번째 공실\n3. 세 번째 공실",
#     "rule_based_intent": ""
# }
# Warning: Skipping data point due to JSONDecodeError: Extra data: line 26 column 5 (char 891)
# Problematic data: {
#     "features": {
#         "group_id": 1909,
#         "columns": {
#             "num_of_company": [215, 213, 216],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [14, 13, 14],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [2, 2, 2],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10615.066432083388, 10633.097783120093, 10635.539377606498],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [3, 3, 3],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["도매업", "도매업", "도매업"],
#             "avg_sales_level": [4.1, 4.1, 4.1]
#         }
#     },
#     "analysis": "",
#     "summary": "",
#     "rule_based_intent": ""
# }
#     현재 공실 데이터에 대한 분석을 통해 어떤 공실이 창업하기에 가장 알맞은지와 그 이유에 대해 알려드릴 것입니다. 잠시만 기다려주세요.
# Warning: Skipping data point due to JSONDecodeError: Expecting property name enclosed in double quotes: line 25 column 1 (char 1163)
# Problematic data: {
#     "features": {
#         "group_id": 2220,
#         "columns": {
#             "num_of_company": [592, 596, 596],
#             "num_of_large": [0, 0, 0],
#             "num_of_bus_stop": [8, 4, 9],
#             "num_of_hospital": [1, 1, 1],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [3, 3, 2],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [6936.881928916749, 6860.749165900308, 6690.544752185848],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 0],
#             "parks_within_500m": [1, 1, 1],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["음식점", "음식점", "음식점"],
#             "avg_sales_level": [3.33, 2.89, 2.78]
#         }
#     },
#     "analysis": "주어진 데이터를 기반으로 분석한 결과, 공실 세 개 중에서 가장 적합한 공실을 선택하기 위해 평균 매출 등급, 인근 인프라, 교통 접근성, 경쟁 강도, 대학교 접근성과 같은 요소를 ganz.wikipeeilig dhekdgo wldydghkdma 다른 전문가로부터 높게 평가되기 위한 공실이 있을 것으로 판단됩니다. ",
#     "summary": "1. 공실 1\n2. 공실 3\n3. 공실 2",
#     "rule_based_intent": "가장 높은 평균 매출 등급과 인근 인프라, 교통 접근성, 경쟁 강도, 대학교 접근성 등을 ganz.wikipeeilig dhdydghkdma",
# }
# Warning: Skipping data point due to JSONDecodeError: Extra data: line 27 column 1 (char 916)
# Problematic data: {
#     "features": {
#         "group_id": 2295,
#         "columns": {
#             "num_of_company": [470, 477, 469],
#             "num_of_large": [0, 0, 0],
#             "num_of_bus_stop": [10, 10, 9],
#             "num_of_hospital": [0, 1, 1],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [8190.682672087187, 8029.530005335545, 7863.598821925951],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["소매업", "소매업", "소매업"],
#             "avg_sales_level": [3.74, 4.06, 3.88]
#         }
#     },
#     "analysis": "",
#     "summary": "1위: 공실 2, 2위: 공실 1, 3위: 공실 3",
#     "rule_based_intent": ""
# }
#
# 분석 결과에 따르면 공실 2가 창업하기 가장 적합한 공실입니다. 이유는 다음과 같습니다:
# 1. 평균 매출 등급: 공실 2의 평균 매출 등급이 4.06으로 가장 높습니다.
# 2. 인근 인프라: 공실 2는 버스 정류장 수가 10개로 다른 공실에 비해 많고, 병원도 1개가 있어 안전한 환경을 제공합니다. 또한 근처에 대학교와 대학병원이 있는 것으로 보아 잠재 고객 유입 요인이 높을 것으로 판단됩니다.
# 3. 교통 접근성: 지하철까지의 거리가 가장 가까운 편이며, 근처에 대중교통 수단이 다양하게 위치해 있어 접근성이 좋습니다.
# 4. 경쟁 강도: 공실 2 주변에 대형 기업체가 없어 경쟁이 덜할 것으로 예상됩니다.
#
# 따라서 공실 2를 우선적으로 고려하고, 그 다음으로는 공실 1을 고려하는 것이 좋습니다.
# Warning: Skipping data point due to JSONDecodeError: Expecting ',' delimiter: line 24 column 5 (char 1653)
# Problematic data: {
#     "features": {
#         "group_id": 3314,
#         "columns": {
#             "num_of_company": [128, 127, 126],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [12, 16, 18],
#             "num_of_hospital": [4, 4, 3],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [4, 4, 1],
#             "nearest_subway_name": ["정평", "정평", "정평"],
#             "nearest_subway_distance": [1726.192632428437, 1722.4668239776563, 1674.2093484533857],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 1, 1],
#             "parking_lots_within_500m": [6, 5, 3],
#             "industry_category": ["미용", "미용", "미용"],
#             "avg_sales_level": [1.0, 1.0, 1.1]
#         }
#     },
#     "analysis": "주어진 3개의 공실 중에서 가장 적합한 공실을 선정하기 위해 다음 요소들을 ganz작히 고려하여 분석하였습니다. 먼저 매출 등급을 고려할 때, 3개의 공실 모두 비슷한 수준의 매출 등급(1.0 또는 1.1)을 보이고 있습니다. 따라서 매출 등급 자체로는 우선순위를 정하기 어렵습니다. 다음으로 인근 인프라 측면에서는 기업체 수, 버스 정류장 수, 병원 수, 주차장, 공원의 유무를 고려해보겠습니다. 공실 1번은 기업체 수, 버스 정류장 수, 병원 수가 비교적 고르게 분포되어 있고, 주차장 수가 가장 많습니다. 공실 2번은 버스 정류장 수와 병원 수가 상대적으로 높은 편이며, 공원이 1개 있습니다. 공실 3번은 병원의 수가 가장 낮고, 버스 정류장 수와 주차장 수는 공실 1번과 비슷합니다. 이를 종합해 볼 때, 인근 인프라로는 공실 1번이 가장 우세하다고 할 수 있습니다. 그리고 교통 접근성 측면에서는 지하철 거리와 지하철 역 수를 고려해 봅니다. 모든 공실이 지하철이 없는 지역에 위치하고 있으며, 지하철까지의 거리는 큰 차이가 없습니다. 따라서 이 요소에서는 차별점을 찾기 어렵습니다. 경쟁 강도 측면에서는 대규모 기업의 유무를 고려해 보았을 때, 공실 1번, 2번, 3번 모두 대규모 기업이 존재하지 않습니다. 마지막으로 대학교 접근성을 살펴보면, 모든 공실이 대학교와의 근접성 면에서 큰 차이가 없습니다. 이에 종합해서 고려해 볼 때, 공실 1번이 인근 인프라 및 주요 요소들을 ganz적으로 고려했을 때 창업하기 가장 알맞다고 판단됩니다.",
#     "summary": "1. 공실 1번 : 매출 등급 1.0, 우수한 인근 인프라 및 주요 요소 보유"
#     "2. 공실 2번 : 매출 등급 1.0, 버스 정류장 수와 병원 수 우수
#     "3. 공실 3번 : 매출 등급 1.1, 병원 수가 다소 부족하지만 주차장 확보 가능",
#     "rule_based_intent": "인근 인프라, 주요 요소 및 매출 등급을 ganz적으로 고려할 때, 공실 1번이 가장 적합하며, 공실 2번과 공실 3번이 순차적으로 이어집니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 393)
# Problematic data: {
#     "features": {
#         "group_id": 3329,
#         "columns": {
#             "num_of_company": [132, 131, 132],
#             "num_of_large": [2, 2, 2],
#             "num_of_bus_stop": [7, 8, 7],
#             "num_of_hospital": [9, 9, 9],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ['임당', '임당', '임당'],
#             "nearest_subway_distance": [973.8219319922326, 1045.00768770417, 986.1324367876782],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [4, 3, 4],
#             "parks_within_500m": [4, 2, 4],
#             "parking_lots_within_500m": [7, 8, 7],
#             "industry_category": ['도매업', '도매업', '도매업'],
#             "avg_sales_level": [4.79, 4.89, 4.82]
#         }
#     },
#     "analysis": "3개의 공실 중에서 가장 적합한 창업 공간을 선택하기 위해 평가 기준을 종합적으로 고려합니다. 먼저, 평균 매출 등급은 4.89로 가장 높은 편이며, 근처에 있는 기업체 수, 버스 정류장 수, 병원 수, 주차장, 공원 등의 인프라가 풍부합니다. 또한, 지하철까지의 거리도 비교적 가깝고, 대학교 접근성이 좋아 잠재 고객 유입이 기대되는 요인입니다. 이러한 분석을 토대로 종합적으로 고려하면 2번 공실이 가장 적합한 창업 공간으로 판단됩니다.",
#     "summary": "1. 2번 공실: 평균 매출 등급이 가장 높고 인프라와 교통 접근성이 우수함.\n2. 1번 공실\n3. 3번 공실",
#     "rule_based_intent": "2번 공실이 가장 적합한 창업 공간으로 판단됩니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 393)
# Problematic data: {
#     "features": {
#         "group_id": 3335,
#         "columns": {
#             "num_of_company": [253, 256, 256],
#             "num_of_large": [0, 0, 0],
#             "num_of_bus_stop": [4, 4, 4],
#             "num_of_hospital": [1, 1, 1],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [596.7685057288652, 550.3185805982055, 537.5947612009509],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [1, 1, 1],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['서비스', '서비스', '서비스'],
#             "avg_sales_level": [2.5, 2.5, 2.5]
#         }
#     },
#     "analysis": "주어진 데이터를 토대로 분석한 결과, 3개의 공실 중 첫 번째와 두 번째 공실은 매출 등급과 인프라 수치가 비슷하나, 세 번째 공실은 지하철과의 거리가 더 가깝고 인근 상가 및 병원 등 인프라가 양호한 편이다. 또한 대학교 주변이라는 점도 고려할 때, 세 번째 공실이 가장 알맞은 공실로 판단된다.",
#     "summary": "1. 세 번째 공실\n2. 첫 번째 공실\n3. 두 번째 공실",
#     "rule_based_intent": "세 번째 공실이 창업하기 가장 알맞는 공실로 평가되었습니다. 대학교 주변에 위치하고 있으며, 지하철과의 거리가 가장 가깝고 인프라 수치 또한 양호한 편입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 79 (char 886)
# Problematic data: {
#     "features": {
#         "group_id": 3372,
#         "columns": {
#             "num_of_company": [83, 83, 87],
#             "num_of_large": [0, 0, 0],
#             "num_of_bus_stop": [13, 12, 16],
#             "num_of_hospital": [2, 2, 2],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 1],
#             "nearest_subway_name": ["정평", "사월", "정평"],
#             "nearest_subway_distance": [1781.457440054829, 1785.141420705633, 1690.4250743690038],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [1, 1, 1],
#             "industry_category": ["의료", "의료", "의료"],
#             "avg_sales_level": [4.71, 6.0, 4.3]
#         }
#     },
#     "analysis": "주어진 공실 정보를 종합적으로 분석한 결과, 공실 2가 가장 적합한 것으로 보입니다. 이유는 다음과 같습니다:\
#     1. 인근 인프라 및 교통 접근성: 공실 2는 버스 정류장 수가 다른 공실들보다 높으며, 주변에 병원과 지하철 역이 있어서 의료 업종에 적합합니다. 또한, 주차장도 있어 고객들의 편의성을 고려한 점이 긍정적입니다.\
#     2. 경쟁 강도: 대규모 기업이 없고, 주변에 병원이 있으나 영화관, 캠프장 등 다양한 엔터테인먼트 시설이 부족한 점에서 경쟁 강도가 낮고, 다양한 서비스 제공으로 시장을 선도할 수 있습니다.\
#     3. 평균 매출 등급: 공실 2는 높은 평균 매출 등급을 보여줍니다. 따라서, 창업을 통해 높은 수익을 기대할 수 있습니다.",
#     "summary": "1. 공실 2\
#                 2. 공실 1\
#                 3. 공실 3",
#     "rule_based_intent": "가장 알맞는 공실은 공실 2이며, 순위는 공실 2 > 공실 1 > 공실 3 입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 393)
# Problematic data: {
#     "features": {
#         "group_id": 3373,
#         "columns": {
#             "num_of_company": [83, 83, 87],
#             "num_of_large": [0, 0, 0],
#             "num_of_bus_stop": [13, 12, 16],
#             "num_of_hospital": [2, 2, 2],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 1],
#             "nearest_subway_name": ['정평', '사월', '정평'],
#             "nearest_subway_distance": [1781.457440054829, 1785.141420705633, 1690.4250743690038],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [1, 1, 1],
#             "industry_category": ['카페 및 베이커리', '카페 및 베이커리', '카페 및 베이커리'],
#             "avg_sales_level": [2.5, 2.0, 2.5]
#         }
#     },
#     "analysis": "주어진 데이터를 종합적으로 분석해보면, 세 공실 모두 카페 및 베이커리 업종이며, 인근 인프라 및 교통 접근성 면에서 큰 차이를 보이지 않습니다. 평균 매출 등급도 비슷하며, 경쟁 요인과 대학교 접근성도 동일합니다.",
#     "summary": "주어진 상황에서 우선순위를 정하기 어렵지만, 인근 지역의 경쟁 업체 밀도와 미래 잠재성을 고려해보면 성공 가능성이 높을 것으로 판단됩니다.",
#     "rule_based_intent": ""
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting ',' delimiter: line 5 column 35 (char 100)
# Problematic data: {
#     "features": {
#         "group_id": 631,
#         "columns": {
#             "num_of_company": [221. 220, 217],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [3, 6, 5],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10693.98845059832, 10684.94092642059, 10633.144466650036],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["교육", "교육", "교육"],
#             "avg_sales_level": [1.29, 1.25, 1.25]
#         }
#     },
#     "analysis": "경산시의 3개 공실은 교육 업종에 속하며, 매출 등급은 비슷한 수준입니다. 인근 인프라와 교통 접근성을 고려해보면, 버스 정류장 수는 6개가 가장 높고, 학교와 대학과의 거리도 가까운 편입니다. 또한, 지하철까지의 거리도 모두 비슷하게 0에 위치하고 있습니다. 경쟁 강도나 관공서 수도 비슷하며, 공원과 주차장은 모두 가용하지 않습니다. 따라서 경쟁적 요소를 고려할 때는 대체로 비슷한 조건을 가지고 있는 것으로 보입니다.",
#     "summary": "1. 첫 번째 우선 순위: 공실 2\n2. 두 번째 우선 순위: 공실 3\n3. 세 번째 우선 순위: 공실 1",
#     "rule_based_intent": "교통 접근성과 인근 인프라 등을 고려할 때, 공실 2가 경쟁 우위를 가지고 있으며, 대체로 유리한 조건을 가지고 있습니다. 이에 따라 공실 2에 집중하여 창업을 진행하는 것이 바람직할 것으로 판단됩니다."
# }
#
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 392)
# Problematic data: {
#     "features": {
#         "group_id": 654,
#         "columns": {
#             "num_of_company": [217, 221, 216],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [5, 3, 5],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 2],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10633.144466650036, 10693.98845059832, 10595.838119470383],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['소매업', '소매업', '소매업'],
#             "avg_sales_level": [4.44, 4.43, 3.97]
#         }
#     },
#     "analysis": "분석 결과, 3개의 공실 중 인근 인프라, 교통 접근성, 경쟁 강도, 대학교 접근성 및 잠재 고객 유입 요인 등을 종합적으로 고려할 때, 공실 1번이 가장 창업하기 적합한 공실로 판단됩니다. 이는 주변 기업체 수와 공원, 주차장 등의 인근 인프라가 풍부하며, 지하철이 가까운 거리에 있고 대학교와도 가까운 위치에 있어 잠재 고객을 유인할 수 있는 요소를 가지고 있기 때문입니다.",
#     "summary": "1. 공실 1번\n2. 공실 3번\n3. 공실 2번",
#     "rule_based_intent": "공실 1번이 창업하기 가장 알맞는 공실로 우선 순위를 매기는 이유는 주변 인프라와 교통 접근성이 우수하며, 대학교와의 근접성 등이 성공 가능성을 높여주기 때문입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Extra data: line 27 column 1 (char 900)
# Problematic data: {
#     "features": {
#         "group_id": 681,
#         "columns": {
#             "num_of_company": [235, 235, 233],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [6, 7, 6],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11472.60454661412, 11402.545758615828, 11190.318206756114],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["미용", "미용", "미용"],
#             "avg_sales_level": [1.0, 1.0, 1.0]
#         }
#     },
#     "analysis": "",
#     "summary": "공실 1 > 공실 3 > 공실 2",
#     "rule_based_intent": ""
# }
#
# 분석 결과, 알맞은 창업 공실은 공실 1입니다. 공실 1은 기업체 수가 높고 대형 기업도 존재하며 버스 정류장 수가 다른 공실에 비해 많은 편입니다. 또한, 근처에 대학교가 위치하여 잠재 고객 유입이 기대됩니다. 또한, 평균 매출 등급이 1.0으로 안정적인 수준을 유지하고 있습니다.
#
# 공실 3은 기업체 수는 낮지만, 다른 요소들에 비해 우세한 점이 없습니다.
#
# 공실 2는 공실 3과 유사한 패턴을 가지고 있지만, 공실 3에 비해 대형 기업이 존재하여 시장 경쟁이 심화되어 있습니다. 따라서, 공실 2는 창업하기에 적합하지 않습니다.
#
# 따라서, 공실 1이 가장 적합하며, 순위는 공실 1 > 공실 3 > 공실 2 입니다.
# Warning: Skipping data point due to JSONDecodeError: Extra data: line 27 column 1 (char 912)
# Problematic data: {
#     "features": {
#         "group_id": 2951,
#         "columns": {
#             "num_of_company": [213, 235, 235],
#             "num_of_large": [0, 1, 1],
#             "num_of_bus_stop": [4, 6, 7],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11636.458741876531, 11472.60454661412, 11402.545758615828],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["소매업", "소매업", "소매업"],
#             "avg_sales_level": [4.6, 4.75, 4.76]
#         }
#     },
#     "analysis": "",
#     "summary": "1. 공실 2\n2. 공실 3\n3. 공실 1",
#     "rule_based_intent": ""
# }
#
# 분석 결과 요약:
# 1. 공실 2가 가장 적합하며, 그 다음으로 공실 3이 적합하고, 마지막으로 공실 1이 적합합니다.
#
# 상세 분석:
# - **공실 2**:
#     - 평균 매출 등급이 가장 높은 수준으로 4.75로, 매출 기반 성과가 높을 것으로 예상됩니다.
#     - 주변 인프라로는 대규모 기업체 수가 1개로 꽤 높은 편이며, 버스 정류장 수도 6개로 꽤 괜찮은 수준입니다.
#     - 주변 환경으로 주차장, 공원, 병원 모두 0개이고, 대학교와 가까운 거리에 위치하면서도 경쟁 업체 수가 적어 상대적으로 경쟁력이 높을 수 있습니다.
#     - 주변 교통으로 지하철까지의 거리가 11472m로 가장 짧고, 지하철 역 수도 0개로 대중교통 이용이 어려울 수 있습니다.
#
# - **공실 3**:
#     - 평균 매출 등급이 4.76으로 공실 2와 유사하게 높은 수준으로 예상됩니다.
#     - 주변 인프라로 대규모 기업체 수가 2개로 더 많으며, 버스 정류장 수도 7개로 높은 편입니다.
#     - 공원, 병원, 대규모 학교 등 주변 환경이 모두 현재 0개이므로 경쟁력 측면에서 유리할 수 있습니다.
#     - 하지만 지하철까지의 거리가 약 11402m로 가장 먼 편에 위치해 대중교통 이용이 어려울 수 있습니다.
#
# - **공실 1**:
#     - 평균 매출 등급은 4.6으로 가장 낮은 편이며, 매출 측면에서는 공실 2와 3보다 하위일 것으로 예상됩니다.
#     - 인프라 측면에서도 대규모 기업체 수가 0개로, 버스 정류장 수도 4개로 가장 낮은 편에 속합니다.
#     - 지하철 거리가 가장 먼 편에 위치하며, 지하철 역 수도 0개로 대중교통 이용이 어려울 것으로 예상됩니다.
#
# 이에 따라, 매출 기반 성과와 인프라 요소 등을 종합적으로 고려할 때, 공실 2가 가장 알맞은 선택이며, 그 다음으로 공실 3, 마지막으로 공실 1이 될 것으로 판단됩니다.
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 396)
# Problematic data: {
#     "features": {
#         "group_id": 2960,
#         "columns": {
#             "num_of_company": [193, 189, 184],
#             "num_of_large": [2, 1, 1],
#             "num_of_bus_stop": [15, 14, 15],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10526.43874248587, 10509.670483980772, 10458.580369192172],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['음식점', '음식점', '음식점'],
#             "avg_sales_level": [2.53, 2.6, 2.73]
#         }
#     },
#     "analysis": "주어진 공실 정보를 종합적으로 분석한 결과, 경산시에 음식점을 창업하고자 할 때, 공실 1이 가장 적합한 위치로 판단됩니다. 이유는 평균 매출 등급이 높고, 기업체 수와 버스 정류장 수가 많으며, 지하철로도 접근이 가능하며 공원과 주차장이 인근에 위치하고 있어 잠재 고객 유입이 용이하기 때문입니다.",
#     "summary": "1. 공실 1\n2. 공실 2\n3. 공실 3",
#     "rule_based_intent": "음식점 창업 시, 공실 1이 우선적으로 고려되어야 함."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 393)
# Problematic data: {
#     "features": {
#         "group_id": 4229,
#         "columns": {
#             "num_of_company": [130, 130, 130],
#             "num_of_large": [2, 2, 2],
#             "num_of_bus_stop": [6, 6, 6],
#             "num_of_hospital": [9, 9, 9],
#             "num_of_theather": [1, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ['정평', '정평', '정평'],
#             "nearest_subway_distance": [1110.3681767942876, 1174.16618242371, 1201.960346143694],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [3, 4, 4],
#             "parks_within_500m": [2, 2, 2],
#             "parking_lots_within_500m": [11, 12, 12],
#             "industry_category": ['유흥주점', '유흥주점', '유흥주점'],
#             "avg_sales_level": [1.71, 1.75, 1.89]
#         }
#     },
#     "analysis": "주어진 데이터를 종합적으로 분석해보면, 세 공실의 평균 매출 등급은 각각 1.71, 1.75, 1.89로 높은 편에 속합니다. 인근 인프라 측면에서는 기업체 수, 버스 정류장 수, 병원 수, 주차장, 공원 등이 모두 비슷한 수준을 보여주고 있습니다. 하지만, 해석과 경험을 토대로 하나의 요인으로 판단하기보다는 여러 요소를 종합적으로 고려해야 합니다. \n\n첫 번째로, 유흥주점 업종의 경우 경쟁이 치열하고 소비자 성향에 따라 변동이 크기 때문에 평균 매출 등급을 주요 고려 대상으로 삼아야 합니다. 두 번째로, 교통 접근성 측면에서는 지하철 거리가 가장 중요한 요소 중 하나이지만, 주변에 지하철이 없고 버스 정류장과 주차장이 충분히 마련되어 있는 것으로 나타났습니다. 따라서, 지하철 거리는 자동차 이용이 주를 이루는 유흥주점 업종에 크게 영향을 미치지 않을 것으로 판단됩니다. \n\n이에, 가장 적합한 공실은 평균 매출 등급이 가장 높은 1.89의 공실이라고 평가됩니다.",
#     "summary": "1위: 공실 3 (평균 매출 등급 1.89)\n2위: 공실 2 (평균 매출 등급 1.75)\n3위: 공실 1 (평균 매출 등급 1.71)",
#     "rule_based_intent": "공실 3 (평균 매출 등급 1.89)이(가) 성공적인 창업을 위한 최적의 선택입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting ':' delimiter: line 24 column 115 (char 1242)
# Problematic data: {
#     "features": {
#         "group_id": 3795,
#         "columns": {
#             "num_of_company": [128, 128, 128],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [10, 10, 8],
#             "num_of_hospital": [7, 7, 9],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [5, 5, 5],
#             "nearest_subway_name": ["정평", "정평", "정평"],
#             "nearest_subway_distance": [1446.1652710070164, 1496.838114750156, 1447.0676825862508],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 2, 2],
#             "parks_within_500m": [1, 1, 1],
#             "parking_lots_within_500m": [6, 7, 6],
#             "industry_category": ["소매업", "소매업", "소매업"],
#             "avg_sales_level": [3.37, 3.34, 3.37]
#         }
#     },
#     "analysis": "주어진 데이터를 토대로 분석해 본 결과, 3개의 공실 중에서 투자할 가치가 있는 위치를 판단하기 위해 다음의 요소들을 종합적으로 고려하여 각 공실들을 평가했습니다. 먼저, 평균 매출 등급이 높을수록 창업 성공 가능성이 높아지며, 인근 인프라와 교통 접근성이 좋을수록 잠재 고객 유입이 원활해집니다. 또한, 경쟁 강도와 대학교 접근성도 고려해야 합니다.",
#     "summary": "1. 공실 1: num_of_company(128), num_of_large(1), avg_sales_level(3.37) -> 이유 설명",
#                "2. 공실 3: num_of_company(128), num_of_large(1), num_of_hospital(9), avg_sales_level(3.37) -> 이유 설명",
#                "3. 공실 2: 미입력",
#     "rule_based_intent": "가장 알맞은 공실은 '공실 1'로, 평균 매출 등급이 높고 기업체 수 및 대형 기업 수도 존재하며, 인근 환경 및 교통 접근성이 양호한 위치입니다. 또한 경쟁이 적어 창업하기에 적합한 조건을 갖추고 있습니다. 따라서 '공실 1'이 성공 가능성이 높을 것으로 판단됩니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 75 (char 881)
# Problematic data: {
#     "features": {
#         "group_id": 4303,
#         "columns": {
#             "num_of_company": [154, 153, 132],
#             "num_of_large": [1, 1, 2],
#             "num_of_bus_stop": [8, 8, 10],
#             "num_of_hospital": [6, 6, 7],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["임당", "임당", "임당"],
#             "nearest_subway_distance": [459.984570116196, 459.0797879102871, 745.5390536945708],
#             "num_of_subway": [1, 1, 0],
#             "num_of_gvn_office": [1, 1, 4],
#             "parks_within_500m": [3, 3, 3],
#             "parking_lots_within_500m": [1, 1, 4],
#             "industry_category": ["의료", "의료", "의료"],
#             "avg_sales_level": [7.0, 4.5, 4.69]
#         }
#     },
#     "analysis": "분석 결과, 공실들 중 가장 성공 가능성이 높은 공실을 선택하기 위해 다음의 요소들을 고려해야 합니다.\
#     먼저, 평균 매출 등급이 높을수록 성공 가능성이 높아지므로 고려해야 합니다. 또한, 인근 인프라 및 교통 접근성이 좋을수록 잠재 고객을 유인할 수 있습니다. \
#     이를 종합적으로 고려하여 최적의 공실을 선정해야 합니다.",
#     "summary": "1위: 공실 1 (평균 매출 등급 7.0, 근처 공원 및 주차장 3개, 지하철 접근 가능)\
#     2위: 공실 3 (평균 매출 등급 4.69, 주변 기업체 수 132개, 주변 병원 7개, 공공기관 사무실 4개)\
#     3위: 공실 2 (평균 매출 등급 4.5, 주변 기업체 수 153개, 주변 버스 정류장 8개, 주변 주차장 1개)",
#     "rule_based_intent": "평균 매출 등급, 인근 인프라 및 교통 접근성이 고려된 결과, 가장 적합한 공실은 공실 1이며, 그 다음으로 공실 3, 공실 2가 뒤를 이었습니다. \
#     공실 1은 평균 매출 등급이 가장 높고 근처 공원과 주차장이 있으며, 지하철 접근이 용이하여 잠재 고객을 유인할 수 있습니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Extra data: line 27 column 1 (char 909)
# Problematic data: {
#     "features": {
#         "group_id": 4316,
#         "columns": {
#             "num_of_company": [161, 158, 158],
#             "num_of_large": [0, 1, 1],
#             "num_of_bus_stop": [8, 10, 10],
#             "num_of_hospital": [3, 2, 2],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [1, 1, 1],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ["정평", "정평", "정평"],
#             "nearest_subway_distance": [2473.604940153341, 2367.571768814149, 2354.236922900522],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 1, 1],
#             "industry_category": ["서비스", "서비스", "서비스"],
#             "avg_sales_level": [1.33, 1.33, 1.33]
#         }
#     },
#     "analysis": "",
#     "summary": "1. 공실 1\n2. 공실 3\n3. 공실 2",
#     "rule_based_intent": ""
# }
#
# 분석 결과에 따르면, 공실 1이 가장 적합한 창업 장소입니다. 이유는 다음과 같습니다:
# - 평균 매출 등급이 높고 인근 인프라 관련 요소들(기업체 수, 버스 정류장 수, 병원 수, 주차장, 공원 등)이 적절하며 경쟁 강도가 적습니다.
# - 교통 접근성 면에서도 지하철까지의 거리가 가장 가깝고, 버스 정류장 수가 적절합니다.
# - 대학교 접근성과 같은 잠재 고객 유입 요인도 고려할 때, 공실 1이 창업하기 가장 적합한 장소로 판단됩니다.
#
# 따라서, 공실 1을 우선적으로 고려하고, 그 다음으로 공실 3을 고려할 수 있습니다. 마지막으로, 공실 2를 세번째로 우선순위로 고려할 수 있습니다.
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 394)
# Problematic data: {
#     "features": {
#         "group_id": 4341,
#         "columns": {
#             "num_of_company": [125, 125, 125],
#             "num_of_large": [2, 2, 2],
#             "num_of_bus_stop": [8, 11, 8],
#             "num_of_hospital": [9, 8, 9],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [2, 2, 2],
#             "nearest_subway_name": ['정평', '정평', '정평'],
#             "nearest_subway_distance": [572.7730462813877, 512.2480293995511, 601.8672560252552],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [3, 2, 3],
#             "parks_within_500m": [5, 5, 5],
#             "parking_lots_within_500m": [5, 5, 5],
#             "industry_category": ['의료', '의료', '의료'],
#             "avg_sales_level": [3.0, 3.25, 3.0]
#         }
#     },
#     "analysis": "주어진 정보를 종합적으로 고려할 때, 경산시에서 의료 업종으로 창업하기에 가장 적합한 공실은 num_of_company가 125, num_of_large가 2, num_of_bus_stop가 11, num_of_hospital가 8, num_of_theather가 1, num_of_camp가 0, num_of_school이 2, nearest_subway_distance가 512m, num_of_gvn_office가 2, parks_within_500m이 5, parking_lots_within_500m가 5, industry_category가 '의료', avg_sales_level이 3.25인 공실입니다.",
#     "summary": "1. 공실 2: num_of_company 125, num_of_large 2, num_of_bus_stop 11, num_of_hospital 8, num_of_theather 1, num_of_camp 0, num_of_school 2, nearest_subway_distance 512m, num_of_gvn_office 2, parks_within_500m 5, parking_lots_within_500m 5, industry_category '의료', avg_sales_level 3.25\n2. 공실 1: num_of_company 125, num_of_large 2, num_of_bus_stop 8, num_of_hospital 9, num_of_theather 1, num_of_camp 0, num_of_school 2, nearest_subway_distance 573m, num_of_gvn_office 3, parks_within_500m 5, parking_lots_within_500m 5, industry_category '의료', avg_sales_level 3.0\n3. 공실 3: num_of_company 125, num_of_large 2, num_of_bus_stop 8, num_of_hospital 9, num_of_theather 1, num_of_camp 0, num_of_school 2, nearest_subway_distance 602m, num_of_gvn_office 3, parks_within_500m 5, parking_lots_within_500m 5, industry_category '의료', avg_sales_level 3.0",
#     "rule_based_intent": "의료 업종 창업 시 경산시 내에서 고려해야 할 요소를 종합하여, 공실 2가 가장 알맞은 창업 공간으로 판단되며, 우선 순위는 공실 2 > 공실 1 > 공실 3 순으로 제시됩니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 396)
# Problematic data: {
#     "features": {
#         "group_id": 4343,
#         "columns": {
#             "num_of_company": [131, 144, 144],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [11, 15, 12],
#             "num_of_hospital": [5, 6, 6],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [5, 4, 4],
#             "nearest_subway_name": ['정평', '정평', '정평'],
#             "nearest_subway_distance": [1775.5359694759916, 1972.804634289264, 1967.576930980881],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [3, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [7, 3, 3],
#             "industry_category": ['미용', '미용', '미용'],
#             "avg_sales_level": [1.0, 1.0, 1.0]
#         }
#     },
#     "analysis": "분석 결과, 3개의 공실 중 창업하기에 가장 적합한 공실을 선택하기 위해 다음 요소들을 종합적으로 고려하였습니다. 먼저, 평균 매출 등급이 모든 공실에서 1.0으로 동일한 수치를 보이고 있어서 이를 기준으로 구분할 수 없었습니다. 그 다음으로, 주변 인프라 면에서는 버스 정류장 수, 병원 수, 주차장 수는 비슷한 수치를 보이고 있으며, 기업체 수와 공원은 모든 공실에서 0이기 때문에 차이가 없습니다. 그러나 대학교 접근성인 학교 수는 5, 4, 4로 다소 차이가 있습니다. 또한, 교통 접근성 측면에서 가장 가까운 지하철 역까지의 거리는 큰 차이를 보이지 않습니다. 따라서, 창업 성공에 가장 도움이 될 수 있는 요소로 대학교 접근성을 우선 고려해야 할 것으로 판단됩니다.",
#     "summary": "1. 대학교 접근성 (학교 수): 1순위, 2. 그 외 요소들: 동일",
#     "rule_based_intent": "대학교 접근성이 창업 성공에 미치는 영향이 가장 크다고 판단되므로 대학교 접근성이 더 좋은 공실을 선택하는 것이 유리할 것으로 추정됩니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 58 (char 867)
# Problematic data: {
#     "features": {
#         "group_id": 3407,
#         "columns": {
#             "num_of_company": [79, 81, 81],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [14, 10, 14],
#             "num_of_hospital": [4, 4, 4],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 1],
#             "nearest_subway_name": ["사월", "사월", "사월"],
#             "nearest_subway_distance": [853.970533029082, 915.2691065276044, 960.4577373574052],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [3, 2, 2],
#             "parking_lots_within_500m": [4, 4, 4],
#             "industry_category": ["음식점", "음식점", "음식점"],
#             "avg_sales_level": [2.22, 2.4, 2.25]
#         }
#     },
#     "analysis": "주어진 데이터를 기반으로 세 공실을 ganzoom 시장 조사에 의하면\n\
# - 공실 1: 평균 매출 등급 2.22로 낮고, 공원 및 주차장은 상대적으로 부족하지만 버스 정류장과 병원은 적당함. 주변에 지하철이 없는 점이 흠.\n\
# - 공실 2: 평균 매출 등급 2.4로 높으며, 주변 버스 정류장은 적고, 공원 및 주차장이 부족함. 병원 수는 적당함.\n\
# - 공실 3: 평균 매출 등급 2.25로 중간 정도이며, 주변 인프라는 적당히 갖춰져 있지만 주변 버스 정류장이 적음. 지하철까지의 거리는 가장 먼 편.",
#     "summary": "1위: 공실 2, 2위: 공실 3, 3위: 공실 1",
#     "rule_based_intent": "위 데이터를 기반으로 평균 매출 등급이 높고, 인근 인프라와 교통 접근성이 적합한 공실이 창업하기 가장 알맞을 것으로 판단됩니다. 따라서, 공실 2가 우선 순위로 선택되어야 합니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Extra data: line 26 column 1 (char 1284)
# Problematic data: {
#     "features": {
#         "group_id": 3434,
#         "columns": {
#             "num_of_company": [135, 135, 136],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [12, 13, 10],
#             "num_of_hospital": [8, 10, 8],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [1, 1, 1],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["임당", "임당", "임당"],
#             "nearest_subway_distance": [1426.894008593707, 1465.6634556447566, 1533.4681580410906],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [4, 4, 4],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [8, 8, 6],
#             "industry_category": ["소매업", "소매업", "소매업"],
#             "avg_sales_level": [3.69, 3.63, 3.52]
#         }
#     },
#     "analysis": "주어진 데이터를 확인한 결과, 3개의 공실 중 우선적으로 고려해야 할 요소는 다음과 같습니다. 가장 높은 평균 매출 등급을 가진 공실은 1번 공실로, 3.69의 평균 매출 등급을 보유하고 있습니다. 인근 인프라 면에서는 회사 수와 병원 수가 다른 공실에 비해 상대적으로 높은 편이며, 또한 주차장의 수도 대체적으로 많은 편입니다. 교통 접근성 측면에서는 지하철 내리막거리도 가장 가깝고, 버스 정류장 수 또한 3개 중 가장 높습니다. 이러한 요소들을 종합적으로 고려할 때, 1번 공실이 창업하기에 가장 알맞다고 판단됩니다.",
#     "summary": "1. 공실 1번\n2. 공실 2번\n3. 공실 3번",
#     "rule_based_intent": "가장 적합한 공실은 1번 공실이며, 이는 평균 매출 등급이 높고, 인근 인프라 및 교통 접근성 면에서 다른 공실들보다 우수하기 때문입니다."
# }
# 위 분석에서는 주어진 데이터를 기반으로 3개의 공실을 종합적으로 평가하여, 1번 공실을 창업하기에 가장 적합한 공실로 선정하였습니다.
# Warning: Skipping data point due to JSONDecodeError: Expecting ':' delimiter: line 11 column 28 (char 344)
# Problematic data: {
#     "features": {
#         "group_id": 3443,
#         "columns": {
#             "num_of_company": [87, 87, 93],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [15, 15, 15],
# ...
#     "summary": "1번 공실 > 3번 공실 > 2번 공실",
#     "rule_based_intent": "1번 공실이 첫 번째 우선순위이며, 3번 공실이 두 번째 우선순위이고, 2번 공실이 세 번째 우선순위입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 72 (char 887)
# Problematic data: {
#     "features": {
#         "group_id": 583,
#         "columns": {
#             "num_of_company": [216, 217, 217],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [5, 5, 6],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [2, 1, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10595.838119470383, 10633.144466650036, 10646.38517617251],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["소매업", "소매업", "소매업"],
#             "avg_sales_level": [3.97, 4.44, 3.97]
#         }
#     },
#     "analysis": "분석 결과, 3개의 공실 중 공실 2가 가장 적합한 공실로 판단됩니다. 이유는 다음과 같습니다. \
#     공실 2는 창업 시 평균 매출 등급이 가장 높은 수치를 보이고 있습니다(4.44). 또한, 인근 인프라 측면에서는 \
#     기업체 수와 버스 정류장 수가 높은 수치를 유지하고 있으며, 대학교(영남대)와의 교통 접근성도 우수한 편입니다. \
#     또한, 경쟁 강도는 낮은 편으로 확인되며, 공원, 주차장, 병원 등의 인프라는 부족하지만, 대학생 등 잠재 고객층을 \
#     고려할 때 매출 상승을 기대할 수 있습니다.",
#     "summary": "1. 공실 2\n2. 공실 1\n3. 공실 3",
#     "rule_based_intent": "공실 2가 가장 적합하며, 공실 1과 3은 차순으로 적합도가 낮음"
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 23 column 102 (char 1141)
# Problematic data: {
#     "features": {
#         "group_id": 2813,
#         "columns": {
#             "num_of_company": [477, 469, 470],
#             "num_of_large": [0, 0, 0],
#             "num_of_bus_stop": [10, 9, 10],
#             "num_of_hospital": [1, 1, 0],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 0, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [8029.530005335545, 7863.598821925951, 8190.682672087187],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [1, 1, 1],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["도매업", "도매업", "도매업"],
#             "avg_sales_level": [4.67, 4.67, 4.0]
#         }
#     },
#     "analysis": "주어진 정보를 종합적으로 살펴보면, 공실 3의 경우 평균 매출 등급이 모두 높은 편에 속하며, 인근 인프라 측면에서는 기업체 수가 많고 학교와 지자체 사무소가 존재하는 것을 확인할 수 있습니다. 또한 교통 접근성 면에서도 버스 정류장 수가 일정 수준 이상 있으며, 가까운 지하철역과의 거리도 멀지 않습니다. 경쟁 강도가 낮고 대학교 접근성도 좋은 것으로 나타납니다.",
#     "summary": "1. **공실 3**: 평균 매출 등급이 높고 인근 인프라 및 교통 접근성 면에서 우수하며, 경쟁 강도가 낮고 대학교 접근성도 좋은 것으로 평가됩니다. \
# 2. **공실 1**: 평균 매출 등급과 인근 인프라는 우수하지만, 교통 접근성 면에서 공실 3보다 약간 떨어집니다. \
# 3. **공실 2**: 평균 매출 등급은 낮고 인근 인프라 및 교통 접근성 측면에서도 다소 미흡한 상황입니다.",
#     "rule_based_intent": "주어진 조건에서는 공실 3이 가장 알맞은 후보로 보입니다. 이유는 평균 매출 등급이 높고 인근 인프라와 교통 접근성 면에서 우수하며, 경쟁 강도가 낮고 대학교 접근성이 좋은 것으로 나타났기 때문입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting value: line 12 column 37 (char 395)
# Problematic data: {
#     "features": {
#         "group_id": 409,
#         "columns": {
#             "num_of_company": [121, 120, 116],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [12, 10, 11],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [0, 0, 0],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 1, 0],
#             "nearest_subway_name": ['영남대', '영남대', '영남대'],
#             "nearest_subway_distance": [10443.658239411248, 10484.005066029456, 10286.074307823174],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 0],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ['음식점', '음식점', '음식점'],
#             "avg_sales_level": [2.0, 2.0, 2.0]
#         }
#     },
#     "analysis": "주어진 3개의 공실은 모두 음식점 업종에 속하며, 평균 매출 등급은 모두 2.0으로 동일합니다. 인근 인프라 측면에서는 기업체 수와 버스 정류장 수가 유사하나 병원, 공원, 주차장 등의 시설은 전부 0입니다. 대학교 접근성은 경산시에서 중요한 요소이며, 모든 공실이 영남대와 가까운 거리에 위치하고 있습니다. 따라서, 이들은 잠재 고객 유입 면에서 살펴봤을 때 경쟁 요인이 유사합니다. 그러나 지하철 거리는 3번 공실이 다소 더 가까운 것으로 나타나며, 이는 교통 접근성을 고려할 때 차별적인 요소로 작용할 수 있습니다. 종합적으로 보았을 때, 3번 공실이 경쟁 강도 측면에서 약간 유리하며 실제로 창업이 성공할 가능성을 조금 더 높일 수 있을 것으로 판단됩니다.",
#     "summary": "3번 > 1번 = 2번",
#     "rule_based_intent": "3번 공실이 가장 알맞은 공실이며, 우선순위는 3번 > 1번 = 2번 입니다."
# }
# Warning: Skipping data point due to JSONDecodeError: Expecting property name enclosed in double quotes: line 25 column 1 (char 1123)
# Problematic data: {
#     "features": {
#         "group_id": 458,
#         "columns": {
#             "num_of_company": [238, 233, 235],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [5, 6, 7],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [0, 0, 0],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [11467.874093239005, 11476.258816602636, 11402.545758615828],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [0, 0, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["음식점", "음식점", "음식점"],
#             "avg_sales_level": [2.73, 2.73, 2.8]
#         }
#     },
#     "analysis": "이 분석에서는 세 공실 중 경쟁 강도, 인근 인프라, 교통 접근성, 대학교 접근성, 평균 매출 등급 등 다양한 요인을 종합적으로 고려하여 최적의 창업 장소를 선정할 것입니다.",
#     "summary": "1. 공실 3\n2. 공실 1\n3. 공실 2",
#     "rule_based_intent": "경쟁 강도가 낮고, 대학교 근접성이 높으며, 인근 인프라 및 교통 접근성이 적절한 '공실 3'이 가장 적합하다. '공실 1'은 경쟁 강도가 다소 높고 '공실 2'는 대학교 근접성이 낮기 때문에 보다 뒷 순위다.",
# }
# Warning: Skipping data point due to JSONDecodeError: Invalid \escape: line 22 column 88 (char 900)
# Problematic data: {
#     "features": {
#         "group_id": 486,
#         "columns": {
#             "num_of_company": [217, 216, 217],
#             "num_of_large": [1, 1, 1],
#             "num_of_bus_stop": [5, 5, 6],
#             "num_of_hospital": [0, 0, 0],
#             "num_of_theather": [1, 1, 1],
#             "num_of_camp": [0, 0, 0],
#             "num_of_school": [1, 2, 1],
#             "nearest_subway_name": ["영남대", "영남대", "영남대"],
#             "nearest_subway_distance": [10633.144466650036, 10595.838119470383, 10646.38517617251],
#             "num_of_subway": [0, 0, 0],
#             "num_of_gvn_office": [2, 2, 2],
#             "parks_within_500m": [0, 0, 0],
#             "parking_lots_within_500m": [0, 0, 0],
#             "industry_category": ["교육", "교육", "교육"],
#             "avg_sales_level": [1.25, 1.25, 1.25]
#         }
#     },
#     "analysis": "주어진 데이터를 종합적으로 분석한 결과, 성공적인 창업을 위해 가장 적합한 공실은 '공실 2'입니다. 이유는 다음과 같습니다.\
#     먼저, '공실 2'는 인근에 대형 기업체가 존재하며, 버스 정류장 수가 다른 공실에 비해 더 많습니다. 또한, 학교가 2개로 다른 공실에 비해 더 많은 교육 시설이 위치해 있습니다. 이는 잠재 고객 유입을 촉진할 수 있습니다.\
#     또한, 주변 경쟁업체인 기타관련 시설의 수가 다른 공실과 비슷하며, 교통 접근성 측면에서도 차별화가 크지 않습니다. 그러나 대학교와 가장 가까운 지하철 역까지의 거리도 다른 공실과 크게 차이나지 않습니다.\
#     따라서, '공실 2'는 다른 공실에 비해 더 많은 기업체와 교육 시설이 위치해 있으며, 이는 창업 성공에 긍정적인 영향을 줄 수 있습니다.",
#     "summary": "1. 공실 2\n2. 공실 1\n3. 공실 3",
#     "rule_based_intent": "가장 알맞은 공실 선택"
# }
# Total data samples: 4509
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [Source]
# 당신은 대한민국 경상북도 경산시 부동산 전문가입니다. 다음 입력정보를 보고 판단하여 공실 우선순위에 대한 분석 결과를 생성하세요.
# ### 입력 정보:
# {
#   "num_of_company": [
#     221,
#     220,
#     217
#   ],
#   "num_of_large": [
#     1,
#     1,
#     1
#   ],
#   "num_of_bus_stop": [
#     3,
#     6,
#     5
#   ],
#   "num_of_hospital": [
#     0,
#     0,
#     0
#   ],
#   "num_of_theather": [
#     1,
#     1,
#     1
#   ],
#   "num_of_camp": [
#     0,
#     0,
#     0
#   ],
#   "num_of_school": [
#     1,
#     1,
#     1
#   ],
#   "nearest_subway_name": [
#     "영남대",
#     "영남대",
#     "영남대"
#   ],
#   "nearest_subway_distance": [
#     10693.98845059832,
#     10684.94092642059,
#     10633.144466650036
#   ],
#   "num_of_subway": [
#     0,
#     0,
#     0
#   ],
#   "num_of_gvn_office": [
#     2,
#     2,
#     2
#   ],
#   "parks_within_500m": [
#     0,
#     0,
#     0
#   ],
#   "parking_lots_within_500m": [
#     0,
#     0,
#     0
#   ],
#   "industry_category": [
#     "의료",
#     "의료",
#     "의료"
#   ],
#   "avg_sales_level": [
#     5.0,
#     4.25,
#     4.33
#   ]
# }
#
# ### 분석 결과:
#
#
# [Target]
#
#
# [Response]
# ### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:
#
# ####################################################################################################
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [Source]
# 당신은 대한민국 경상북도 경산시 부동산 전문가입니다. 다음 입력정보를 보고 판단하여 공실 우선순위에 대한 분석 결과를 생성하세요.
# ### 입력 정보:
# {
#   "num_of_company": [
#     213,
#     235,
#     235
#   ],
#   "num_of_large": [
#     0,
#     1,
#     1
#   ],
#   "num_of_bus_stop": [
#     4,
#     6,
#     7
#   ],
#   "num_of_hospital": [
#     0,
#     0,
#     0
#   ],
#   "num_of_theather": [
#     1,
#     1,
#     1
#   ],
#   "num_of_camp": [
#     0,
#     0,
#     0
#   ],
#   "num_of_school": [
#     0,
#     0,
#     0
#   ],
#   "nearest_subway_name": [
#     "영남대",
#     "영남대",
#     "영남대"
#   ],
#   "nearest_subway_distance": [
#     11636.458741876531,
#     11472.60454661412,
#     11402.545758615828
#   ],
#   "num_of_subway": [
#     0,
#     0,
#     0
#   ],
#   "num_of_gvn_office": [
#     0,
#     0,
#     2
#   ],
#   "parks_within_500m": [
#     0,
#     0,
#     0
#   ],
#   "parking_lots_within_500m": [
#     0,
#     0,
#     0
#   ],
#   "industry_category": [
#     "음식점",
#     "음식점",
#     "음식점"
#   ],
#   "avg_sales_level": [
#     3.0,
#     2.82,
#     2.8
#   ]
# }
#
# ### 분석 결과:
#
#
# [Target]
# 분석 결과, 3개 공실 중 최적의 창업 위치는 group_id가 102인 2번째 공실입니다. 이유는 다음과 같습니다. 1) 인근 인프라 및 교통접근성: 2번째 공실은 회사 수, 버스 정류장 수, 대학교 및 지하철과의 거리 등 인프라 및 교통 접근성이 가장 우수하며, 이는 잠재 고객의 유입에 유리한 조건을 제공합니다. 2) 경쟁 강도: 경쟁 업체가 적은 2번째 공실은 시장 진입 장벽이 낮고, 새로운 사업이 경쟁력을 갖출 수 있을 것으로 판단됩니다. 3) 평균 매출 등급: 2번째 공실의 음식점 평균 매출 등급이 가장 안정적으로 유지되고 있어, 성공적인 창업이 기대됩니다.
#
# [Response]
# ### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:
#
# ####################################################################################################
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [Source]
# 당신은 대한민국 경상북도 경산시 부동산 전문가입니다. 다음 입력정보를 보고 판단하여 공실 우선순위에 대한 분석 결과를 생성하세요.
# ### 입력 정보:
# {
#   "num_of_company": [
#     213,
#     235,
#     235
#   ],
#   "num_of_large": [
#     0,
#     1,
#     1
#   ],
#   "num_of_bus_stop": [
#     4,
#     6,
#     7
#   ],
#   "num_of_hospital": [
#     0,
#     0,
#     0
#   ],
#   "num_of_theather": [
#     1,
#     1,
#     1
#   ],
#   "num_of_camp": [
#     0,
#     0,
#     0
#   ],
#   "num_of_school": [
#     0,
#     0,
#     0
#   ],
#   "nearest_subway_name": [
#     "영남대",
#     "영남대",
#     "영남대"
#   ],
#   "nearest_subway_distance": [
#     11636.458741876531,
#     11472.60454661412,
#     11402.545758615828
#   ],
#   "num_of_subway": [
#     0,
#     0,
#     0
#   ],
#   "num_of_gvn_office": [
#     0,
#     0,
#     2
#   ],
#   "parks_within_500m": [
#     0,
#     0,
#     0
#   ],
#   "parking_lots_within_500m": [
#     0,
#     0,
#     0
#   ],
#   "industry_category": [
#     "소매업",
#     "소매업",
#     "소매업"
#   ],
#   "avg_sales_level": [
#     4.6,
#     4.75,
#     4.76
#   ]
# }
#
# ### 분석 결과:
#
#
# [Target]
#
#
# [Response]
# ### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:
#
# ####################################################################################################
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [Source]
# 당신은 대한민국 경상북도 경산시 부동산 전문가입니다. 다음 입력정보를 보고 판단하여 공실 우선순위에 대한 분석 결과를 생성하세요.
# ### 입력 정보:
# {
#   "num_of_company": [
#     213,
#     235,
#     235
#   ],
#   "num_of_large": [
#     0,
#     1,
#     1
#   ],
#   "num_of_bus_stop": [
#     4,
#     6,
#     7
#   ],
#   "num_of_hospital": [
#     0,
#     0,
#     0
#   ],
#   "num_of_theather": [
#     1,
#     1,
#     1
#   ],
#   "num_of_camp": [
#     0,
#     0,
#     0
#   ],
#   "num_of_school": [
#     0,
#     0,
#     0
#   ],
#   "nearest_subway_name": [
#     "영남대",
#     "영남대",
#     "영남대"
#   ],
#   "nearest_subway_distance": [
#     11636.458741876531,
#     11472.60454661412,
#     11402.545758615828
#   ],
#   "num_of_subway": [
#     0,
#     0,
#     0
#   ],
#   "num_of_gvn_office": [
#     0,
#     0,
#     2
#   ],
#   "parks_within_500m": [
#     0,
#     0,
#     0
#   ],
#   "parking_lots_within_500m": [
#     0,
#     0,
#     0
#   ],
#   "industry_category": [
#     "도매업",
#     "도매업",
#     "도매업"
#   ],
#   "avg_sales_level": [
#     4.0,
#     1.5,
#     3.25
#   ]
# }
#
# ### 분석 결과:
#
#
# [Target]
# 주어진 정보를 종합적으로 분석해보면, 성공적인 창업을 위해서는 다음 요인을 고려해야 합니다. 첫째로, 평균 매출 등급은 공실 1이 4.0으로 가장 높으며, 이는 매출 성과가 높을 가능성을 시사합니다. 둘째로, 공실 3은 주변에 지하철 역이 가까이 있고, 행정기관의 입지가 있어 교통 접근성 및 협력 기회가 다른 공실에 비해 우수합니다. 세번째로, 공실 2는 대기업의 입지가 있는 등 교통 편의 시설이 보다 잘 갖춰져 있습니다. 다만, 매출 등급이 다소 낮은 것이 단점입니다.
#
# [Response]
# ### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:
#
# ####################################################################################################
#
#
#
# [Source]
# 당신은 대한민국 경상북도 경산시 부동산 전문가입니다. 다음 입력정보를 보고 판단하여 공실 우선순위에 대한 분석 결과를 생성하세요.
# ### 입력 정보:
# {
#   "num_of_company": [
#     221,
#     217,
#     220
#   ],
#   "num_of_large": [
#     1,
#     1,
#     1
#   ],
#   "num_of_bus_stop": [
#     3,
#     5,
#     6
#   ],
#   "num_of_hospital": [
#     0,
#     0,
#     0
#   ],
#   "num_of_theather": [
#     1,
#     1,
#     1
#   ],
#   "num_of_camp": [
#     0,
#     0,
#     0
#   ],
#   "num_of_school": [
#     1,
#     1,
#     1
#   ],
#   "nearest_subway_name": [
#     "영남대",
#     "영남대",
#     "영남대"
#   ],
#   "nearest_subway_distance": [
#     10693.98845059832,
#     10633.144466650036,
#     10684.94092642059
#   ],
#   "num_of_subway": [
#     0,
#     0,
#     0
#   ],
#   "num_of_gvn_office": [
#     2,
#     2,
#     2
#   ],
#   "parks_within_500m": [
#     0,
#     0,
#     0
#   ],
#   "parking_lots_within_500m": [
#     0,
#     0,
#     0
#   ],
#   "industry_category": [
#     "음식점",
#     "음식점",
#     "음식점"
#   ],
#   "avg_sales_level": [
#     2.69,
#     2.62,
#     2.64
#   ]
# }
#
# ### 분석 결과:
#
#
# [Target]
# 주요 평가 기준으로는 다음과 같이 평가할 수 있습니다:
# 1. 평균 매출 등급: 2.69, 2.62, 2.64로 유의미한 차이가 없음.
# 2. 인근 인프라: 기업체 수와 버스 정류장 수는 220-221개로 공실들 간에 유사하며, 병원, 주차장, 공원 등의 수는 0으로 동일함.
# 3. 교통 접근성: 지하철까지의 거리도 유의미한 차이가 없음. 버스 정류장 수는 공실 3이 가장 높음.
# 4. 경쟁 강도: 대학 가까이 위치해 경쟁이 치열할 것으로 예상됨.
# 5. 대학교 접근성: 모든 공실이 영남대가 가까운 위치에 있음.
#
# [Response]
# ### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:션### 입력 정보:
#
# ####################################################################################################

# %%
#workspace/LoRA1/outputs/polyglot-ko-1.3b/test/final/adapter_config.json

# %%
# !nvidia-smi
# Out:
# Wed Dec 25 09:09:12 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100 80GB PCIe          On  |   00000000:81:00.0 Off |                    0 |
# | N/A   35C    P0             61W /  300W |   81139MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
